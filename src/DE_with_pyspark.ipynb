# %%
# import os, sys
# os.environ["PYSPARK_PYTHON"] = sys.executable
# os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %%
# Importing Necessary modules
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import sum, count
from pyspark.sql.functions import first, explode
from pyspark.sql.functions import round, when, dayofweek
from pyspark.sql.functions import col
from pyspark.sql.functions import split, udf, concat_ws
from pyspark.ml.feature import StopWordsRemover
from pyspark.sql.types import ArrayType, StringType, IntegerType,  StructType, \
                    StructField, DoubleType

import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from src import constants

# %%
spark = SparkSession.builder.appName("appName").config("spark.driver.extraClassPath", "C:\\mysql-connector-j-8.0.33.jar").getOrCreate()

# %% [markdown]
# # 1. Load Data

# %% [markdown]
# ## Q1) 1.1 Load data from MySQL

# %%
def load_data_from_mysql(spark :pyspark.sql.SparkSession, db_name :str, table_name :str) \
                        -> pyspark.sql.DataFrame:
    '''
        – load data from MySQL table 'table_name' from database 'db_name' and return the 
          table as a spark dataframe

        For the mysql connection use below information:
            jdbc driver: 'com.mysql.cj.jdbc.Driver'
            Hostname: 'localhost'
            Port: 3306
            Database: 'classicmodels'
            Table_name: 'order_details'
            Username: 'mysql_user'
            Password: 'user'
    '''

    spark_df = spark.read \
        .format("jdbc") \
        .option("driver","com.mysql.cj.jdbc.Driver") \
        .option("url", "jdbc:mysql://localhost:3306/"+db_name) \
        .option("dbtable", table_name) \
        .option("user", "mysql_user") \
        .option("password", "user") \
        .load()
    # print(spark_df.show(truncate=False))
    return spark_df

# %%
for row in load_data_from_mysql(spark, "classicmodels", 'orderdetails').collect():
    print(row)
# Out:
# Row(orderNumber=10100, productCode='S18_1749', quantityOrdered=30, priceEach=Decimal('136.00'), orderLineNumber=3)
# Row(orderNumber=10100, productCode='S18_2248', quantityOrdered=50, priceEach=Decimal('55.09'), orderLineNumber=2)
# Row(orderNumber=10100, productCode='S18_4409', quantityOrdered=22, priceEach=Decimal('75.46'), orderLineNumber=4)
# Row(orderNumber=10100, productCode='S24_3969', quantityOrdered=49, priceEach=Decimal('35.29'), orderLineNumber=1)
# Row(orderNumber=10101, productCode='S18_2325', quantityOrdered=25, priceEach=Decimal('108.06'), orderLineNumber=4)
# Row(orderNumber=10101, productCode='S18_2795', quantityOrdered=26, priceEach=Decimal('167.06'), orderLineNumber=1)
# Row(orderNumber=10101, productCode='S24_1937', quantityOrdered=45, priceEach=Decimal('32.53'), orderLineNumber=3)
# Row(orderNumber=10101, productCode='S24_2022', quantityOrdered=46, priceEach=Decimal('44.35'), orderLineNumber=2)
# Row(orderNumber=10102, productCode='S18_1342', quantityOrdered=39, priceEach=Decimal('95.55'), orderLineNumber=2)
# Row(orderNumber=10102, productCode='S18_1367', quantityOrdered=41, priceEach=Decimal('43.13'), orderLineNumber=1)
# Row(orderNumber=10103, productCode='S10_1949', quantityOrdered=26, priceEach=Decimal('214.30'), orderLineNumber=11)
# Row(orderNumber=10103, productCode='S10_4962', quantityOrdered=42, priceEach=Decimal('119.67'), orderLineNumber=4)
# Row(orderNumber=10103, productCode='S12_1666', quantityOrdered=27, priceEach=Decimal('121.64'), orderLineNumber=8)
# Row(orderNumber=10103, productCode='S18_1097', quantityOrdered=35, priceEach=Decimal('94.50'), orderLineNumber=10)
# Row(orderNumber=10103, productCode='S18_2432', quantityOrdered=22, priceEach=Decimal('58.34'), orderLineNumber=2)
# Row(orderNumber=10103, productCode='S18_2949', quantityOrdered=27, priceEach=Decimal('92.19'), orderLineNumber=12)
# Row(orderNumber=10103, productCode='S18_2957', quantityOrdered=35, priceEach=Decimal('61.84'), orderLineNumber=14)
# Row(orderNumber=10103, productCode='S18_3136', quantityOrdered=25, priceEach=Decimal('86.92'), orderLineNumber=13)
# Row(orderNumber=10103, productCode='S18_3320', quantityOrdered=46, priceEach=Decimal('86.31'), orderLineNumber=16)
# Row(orderNumber=10103, productCode='S18_4600', quantityOrdered=36, priceEach=Decimal('98.07'), orderLineNumber=5)
# Row(orderNumber=10103, productCode='S18_4668', quantityOrdered=41, priceEach=Decimal('40.75'), orderLineNumber=9)
# Row(orderNumber=10103, productCode='S24_2300', quantityOrdered=36, priceEach=Decimal('107.34'), orderLineNumber=1)
# Row(orderNumber=10103, productCode='S24_4258', quantityOrdered=25, priceEach=Decimal('88.62'), orderLineNumber=15)
# Row(orderNumber=10103, productCode='S32_1268', quantityOrdered=31, priceEach=Decimal('92.46'), orderLineNumber=3)
# Row(orderNumber=10103, productCode='S32_3522', quantityOrdered=45, priceEach=Decimal('63.35'), orderLineNumber=7)
# Row(orderNumber=10103, productCode='S700_2824', quantityOrdered=42, priceEach=Decimal('94.07'), orderLineNumber=6)
# Row(orderNumber=10104, productCode='S12_3148', quantityOrdered=34, priceEach=Decimal('131.44'), orderLineNumber=1)
# Row(orderNumber=10104, productCode='S12_4473', quantityOrdered=41, priceEach=Decimal('111.39'), orderLineNumber=9)
# Row(orderNumber=10104, productCode='S18_2238', quantityOrdered=24, priceEach=Decimal('135.90'), orderLineNumber=8)
# Row(orderNumber=10104, productCode='S18_2319', quantityOrdered=29, priceEach=Decimal('122.73'), orderLineNumber=12)
# Row(orderNumber=10104, productCode='S18_3232', quantityOrdered=23, priceEach=Decimal('165.95'), orderLineNumber=13)
# Row(orderNumber=10104, productCode='S18_4027', quantityOrdered=38, priceEach=Decimal('119.20'), orderLineNumber=3)
# Row(orderNumber=10104, productCode='S24_1444', quantityOrdered=35, priceEach=Decimal('52.02'), orderLineNumber=6)
# Row(orderNumber=10104, productCode='S24_2840', quantityOrdered=44, priceEach=Decimal('30.41'), orderLineNumber=10)
# Row(orderNumber=10104, productCode='S24_4048', quantityOrdered=26, priceEach=Decimal('106.45'), orderLineNumber=5)
# Row(orderNumber=10104, productCode='S32_2509', quantityOrdered=35, priceEach=Decimal('51.95'), orderLineNumber=11)
# Row(orderNumber=10104, productCode='S32_3207', quantityOrdered=49, priceEach=Decimal('56.55'), orderLineNumber=4)
# Row(orderNumber=10104, productCode='S50_1392', quantityOrdered=33, priceEach=Decimal('114.59'), orderLineNumber=7)
# Row(orderNumber=10104, productCode='S50_1514', quantityOrdered=32, priceEach=Decimal('53.31'), orderLineNumber=2)
# Row(orderNumber=10105, productCode='S10_4757', quantityOrdered=50, priceEach=Decimal('127.84'), orderLineNumber=2)
# Row(orderNumber=10105, productCode='S12_1108', quantityOrdered=41, priceEach=Decimal('205.72'), orderLineNumber=15)
# Row(orderNumber=10105, productCode='S12_3891', quantityOrdered=29, priceEach=Decimal('141.88'), orderLineNumber=14)
# Row(orderNumber=10105, productCode='S18_3140', quantityOrdered=22, priceEach=Decimal('136.59'), orderLineNumber=11)
# Row(orderNumber=10105, productCode='S18_3259', quantityOrdered=38, priceEach=Decimal('87.73'), orderLineNumber=13)
# Row(orderNumber=10105, productCode='S18_4522', quantityOrdered=41, priceEach=Decimal('75.48'), orderLineNumber=10)
# Row(orderNumber=10105, productCode='S24_2011', quantityOrdered=43, priceEach=Decimal('117.97'), orderLineNumber=9)
# Row(orderNumber=10105, productCode='S24_3151', quantityOrdered=44, priceEach=Decimal('73.46'), orderLineNumber=4)
# Row(orderNumber=10105, productCode='S24_3816', quantityOrdered=50, priceEach=Decimal('75.47'), orderLineNumber=1)
# Row(orderNumber=10105, productCode='S700_1138', quantityOrdered=41, priceEach=Decimal('54.00'), orderLineNumber=5)
# Row(orderNumber=10105, productCode='S700_1938', quantityOrdered=29, priceEach=Decimal('86.61'), orderLineNumber=12)
# Row(orderNumber=10105, productCode='S700_2610', quantityOrdered=31, priceEach=Decimal('60.72'), orderLineNumber=3)
# Row(orderNumber=10105, productCode='S700_3505', quantityOrdered=39, priceEach=Decimal('92.16'), orderLineNumber=6)
# Row(orderNumber=10105, productCode='S700_3962', quantityOrdered=22, priceEach=Decimal('99.31'), orderLineNumber=7)
# Row(orderNumber=10105, productCode='S72_3212', quantityOrdered=25, priceEach=Decimal('44.77'), orderLineNumber=8)
# Row(orderNumber=10106, productCode='S18_1662', quantityOrdered=36, priceEach=Decimal('134.04'), orderLineNumber=12)
# Row(orderNumber=10106, productCode='S18_2581', quantityOrdered=34, priceEach=Decimal('81.10'), orderLineNumber=2)
# Row(orderNumber=10106, productCode='S18_3029', quantityOrdered=41, priceEach=Decimal('80.86'), orderLineNumber=18)
# Row(orderNumber=10106, productCode='S18_3856', quantityOrdered=41, priceEach=Decimal('94.22'), orderLineNumber=17)
# Row(orderNumber=10106, productCode='S24_1785', quantityOrdered=28, priceEach=Decimal('107.23'), orderLineNumber=4)
# Row(orderNumber=10106, productCode='S24_2841', quantityOrdered=49, priceEach=Decimal('65.77'), orderLineNumber=13)
# Row(orderNumber=10106, productCode='S24_3420', quantityOrdered=31, priceEach=Decimal('55.89'), orderLineNumber=14)
# Row(orderNumber=10106, productCode='S24_3949', quantityOrdered=50, priceEach=Decimal('55.96'), orderLineNumber=11)
# Row(orderNumber=10106, productCode='S24_4278', quantityOrdered=26, priceEach=Decimal('71.00'), orderLineNumber=3)
# Row(orderNumber=10106, productCode='S32_4289', quantityOrdered=33, priceEach=Decimal('65.35'), orderLineNumber=5)
# Row(orderNumber=10106, productCode='S50_1341', quantityOrdered=39, priceEach=Decimal('35.78'), orderLineNumber=6)
# Row(orderNumber=10106, productCode='S700_1691', quantityOrdered=31, priceEach=Decimal('91.34'), orderLineNumber=7)
# Row(orderNumber=10106, productCode='S700_2047', quantityOrdered=30, priceEach=Decimal('85.09'), orderLineNumber=16)
# Row(orderNumber=10106, productCode='S700_2466', quantityOrdered=34, priceEach=Decimal('99.72'), orderLineNumber=9)
# Row(orderNumber=10106, productCode='S700_2834', quantityOrdered=32, priceEach=Decimal('113.90'), orderLineNumber=1)
# Row(orderNumber=10106, productCode='S700_3167', quantityOrdered=44, priceEach=Decimal('76.00'), orderLineNumber=8)
# Row(orderNumber=10106, productCode='S700_4002', quantityOrdered=48, priceEach=Decimal('70.33'), orderLineNumber=10)
# Row(orderNumber=10106, productCode='S72_1253', quantityOrdered=48, priceEach=Decimal('43.70'), orderLineNumber=15)
# Row(orderNumber=10107, productCode='S10_1678', quantityOrdered=30, priceEach=Decimal('81.35'), orderLineNumber=2)
# Row(orderNumber=10107, productCode='S10_2016', quantityOrdered=39, priceEach=Decimal('105.86'), orderLineNumber=5)
# Row(orderNumber=10107, productCode='S10_4698', quantityOrdered=27, priceEach=Decimal('172.36'), orderLineNumber=4)
# Row(orderNumber=10107, productCode='S12_2823', quantityOrdered=21, priceEach=Decimal('122.00'), orderLineNumber=1)
# Row(orderNumber=10107, productCode='S18_2625', quantityOrdered=29, priceEach=Decimal('52.70'), orderLineNumber=6)
# Row(orderNumber=10107, productCode='S24_1578', quantityOrdered=25, priceEach=Decimal('96.92'), orderLineNumber=3)
# Row(orderNumber=10107, productCode='S24_2000', quantityOrdered=38, priceEach=Decimal('73.12'), orderLineNumber=7)
# Row(orderNumber=10107, productCode='S32_1374', quantityOrdered=20, priceEach=Decimal('88.90'), orderLineNumber=8)
# Row(orderNumber=10108, productCode='S12_1099', quantityOrdered=33, priceEach=Decimal('165.38'), orderLineNumber=6)
# Row(orderNumber=10108, productCode='S12_3380', quantityOrdered=45, priceEach=Decimal('96.30'), orderLineNumber=4)
# Row(orderNumber=10108, productCode='S12_3990', quantityOrdered=39, priceEach=Decimal('75.81'), orderLineNumber=7)
# Row(orderNumber=10108, productCode='S12_4675', quantityOrdered=36, priceEach=Decimal('107.10'), orderLineNumber=3)
# Row(orderNumber=10108, productCode='S18_1889', quantityOrdered=38, priceEach=Decimal('67.76'), orderLineNumber=2)
# Row(orderNumber=10108, productCode='S18_3278', quantityOrdered=26, priceEach=Decimal('73.17'), orderLineNumber=9)
# Row(orderNumber=10108, productCode='S18_3482', quantityOrdered=29, priceEach=Decimal('132.29'), orderLineNumber=8)
# Row(orderNumber=10108, productCode='S18_3782', quantityOrdered=43, priceEach=Decimal('52.84'), orderLineNumber=12)
# Row(orderNumber=10108, productCode='S18_4721', quantityOrdered=44, priceEach=Decimal('139.87'), orderLineNumber=11)
# Row(orderNumber=10108, productCode='S24_2360', quantityOrdered=35, priceEach=Decimal('64.41'), orderLineNumber=15)
# Row(orderNumber=10108, productCode='S24_3371', quantityOrdered=30, priceEach=Decimal('60.01'), orderLineNumber=5)
# Row(orderNumber=10108, productCode='S24_3856', quantityOrdered=40, priceEach=Decimal('132.00'), orderLineNumber=1)
# Row(orderNumber=10108, productCode='S24_4620', quantityOrdered=31, priceEach=Decimal('67.10'), orderLineNumber=10)
# Row(orderNumber=10108, productCode='S32_2206', quantityOrdered=27, priceEach=Decimal('36.21'), orderLineNumber=13)
# Row(orderNumber=10108, productCode='S32_4485', quantityOrdered=31, priceEach=Decimal('87.76'), orderLineNumber=16)
# Row(orderNumber=10108, productCode='S50_4713', quantityOrdered=34, priceEach=Decimal('74.85'), orderLineNumber=14)
# Row(orderNumber=10109, productCode='S18_1129', quantityOrdered=26, priceEach=Decimal('117.48'), orderLineNumber=4)
# Row(orderNumber=10109, productCode='S18_1984', quantityOrdered=38, priceEach=Decimal('137.98'), orderLineNumber=3)
# Row(orderNumber=10109, productCode='S18_2870', quantityOrdered=26, priceEach=Decimal('126.72'), orderLineNumber=1)
# Row(orderNumber=10109, productCode='S18_3232', quantityOrdered=46, priceEach=Decimal('160.87'), orderLineNumber=5)
# Row(orderNumber=10109, productCode='S18_3685', quantityOrdered=47, priceEach=Decimal('125.74'), orderLineNumber=2)
# Row(orderNumber=10109, productCode='S24_2972', quantityOrdered=29, priceEach=Decimal('32.10'), orderLineNumber=6)
# Row(orderNumber=10110, productCode='S18_1589', quantityOrdered=37, priceEach=Decimal('118.22'), orderLineNumber=16)
# Row(orderNumber=10110, productCode='S18_1749', quantityOrdered=42, priceEach=Decimal('153.00'), orderLineNumber=7)
# Row(orderNumber=10110, productCode='S18_2248', quantityOrdered=32, priceEach=Decimal('51.46'), orderLineNumber=6)
# Row(orderNumber=10110, productCode='S18_2325', quantityOrdered=33, priceEach=Decimal('115.69'), orderLineNumber=4)
# Row(orderNumber=10110, productCode='S18_2795', quantityOrdered=31, priceEach=Decimal('163.69'), orderLineNumber=1)
# Row(orderNumber=10110, productCode='S18_4409', quantityOrdered=28, priceEach=Decimal('81.91'), orderLineNumber=8)
# Row(orderNumber=10110, productCode='S18_4933', quantityOrdered=42, priceEach=Decimal('62.00'), orderLineNumber=9)
# Row(orderNumber=10110, productCode='S24_1046', quantityOrdered=36, priceEach=Decimal('72.02'), orderLineNumber=13)
# Row(orderNumber=10110, productCode='S24_1628', quantityOrdered=29, priceEach=Decimal('43.27'), orderLineNumber=15)
# Row(orderNumber=10110, productCode='S24_1937', quantityOrdered=20, priceEach=Decimal('28.88'), orderLineNumber=3)
# Row(orderNumber=10110, productCode='S24_2022', quantityOrdered=39, priceEach=Decimal('40.77'), orderLineNumber=2)
# Row(orderNumber=10110, productCode='S24_2766', quantityOrdered=43, priceEach=Decimal('82.69'), orderLineNumber=11)
# Row(orderNumber=10110, productCode='S24_2887', quantityOrdered=46, priceEach=Decimal('112.74'), orderLineNumber=10)
# Row(orderNumber=10110, productCode='S24_3191', quantityOrdered=27, priceEach=Decimal('80.47'), orderLineNumber=12)
# Row(orderNumber=10110, productCode='S24_3432', quantityOrdered=37, priceEach=Decimal('96.37'), orderLineNumber=14)
# Row(orderNumber=10110, productCode='S24_3969', quantityOrdered=48, priceEach=Decimal('35.29'), orderLineNumber=5)
# Row(orderNumber=10111, productCode='S18_1342', quantityOrdered=33, priceEach=Decimal('87.33'), orderLineNumber=6)
# Row(orderNumber=10111, productCode='S18_1367', quantityOrdered=48, priceEach=Decimal('48.52'), orderLineNumber=5)
# Row(orderNumber=10111, productCode='S18_2957', quantityOrdered=28, priceEach=Decimal('53.09'), orderLineNumber=2)
# Row(orderNumber=10111, productCode='S18_3136', quantityOrdered=43, priceEach=Decimal('94.25'), orderLineNumber=1)
# Row(orderNumber=10111, productCode='S18_3320', quantityOrdered=39, priceEach=Decimal('91.27'), orderLineNumber=4)
# Row(orderNumber=10111, productCode='S24_4258', quantityOrdered=26, priceEach=Decimal('85.70'), orderLineNumber=3)
# Row(orderNumber=10112, productCode='S10_1949', quantityOrdered=29, priceEach=Decimal('197.16'), orderLineNumber=1)
# Row(orderNumber=10112, productCode='S18_2949', quantityOrdered=23, priceEach=Decimal('85.10'), orderLineNumber=2)
# Row(orderNumber=10113, productCode='S12_1666', quantityOrdered=21, priceEach=Decimal('121.64'), orderLineNumber=2)
# Row(orderNumber=10113, productCode='S18_1097', quantityOrdered=49, priceEach=Decimal('101.50'), orderLineNumber=4)
# Row(orderNumber=10113, productCode='S18_4668', quantityOrdered=50, priceEach=Decimal('43.27'), orderLineNumber=3)
# Row(orderNumber=10113, productCode='S32_3522', quantityOrdered=23, priceEach=Decimal('58.82'), orderLineNumber=1)
# Row(orderNumber=10114, productCode='S10_4962', quantityOrdered=31, priceEach=Decimal('128.53'), orderLineNumber=8)
# Row(orderNumber=10114, productCode='S18_2319', quantityOrdered=39, priceEach=Decimal('106.78'), orderLineNumber=3)
# Row(orderNumber=10114, productCode='S18_2432', quantityOrdered=45, priceEach=Decimal('53.48'), orderLineNumber=6)
# Row(orderNumber=10114, productCode='S18_3232', quantityOrdered=48, priceEach=Decimal('169.34'), orderLineNumber=4)
# Row(orderNumber=10114, productCode='S18_4600', quantityOrdered=41, priceEach=Decimal('105.34'), orderLineNumber=9)
# Row(orderNumber=10114, productCode='S24_2300', quantityOrdered=21, priceEach=Decimal('102.23'), orderLineNumber=5)
# Row(orderNumber=10114, productCode='S24_2840', quantityOrdered=24, priceEach=Decimal('28.64'), orderLineNumber=1)
# Row(orderNumber=10114, productCode='S32_1268', quantityOrdered=32, priceEach=Decimal('88.61'), orderLineNumber=7)
# Row(orderNumber=10114, productCode='S32_2509', quantityOrdered=28, priceEach=Decimal('43.83'), orderLineNumber=2)
# Row(orderNumber=10114, productCode='S700_2824', quantityOrdered=42, priceEach=Decimal('82.94'), orderLineNumber=10)
# Row(orderNumber=10115, productCode='S12_4473', quantityOrdered=46, priceEach=Decimal('111.39'), orderLineNumber=5)
# Row(orderNumber=10115, productCode='S18_2238', quantityOrdered=46, priceEach=Decimal('140.81'), orderLineNumber=4)
# Row(orderNumber=10115, productCode='S24_1444', quantityOrdered=47, priceEach=Decimal('56.64'), orderLineNumber=2)
# Row(orderNumber=10115, productCode='S24_4048', quantityOrdered=44, priceEach=Decimal('106.45'), orderLineNumber=1)
# Row(orderNumber=10115, productCode='S50_1392', quantityOrdered=27, priceEach=Decimal('100.70'), orderLineNumber=3)
# Row(orderNumber=10116, productCode='S32_3207', quantityOrdered=27, priceEach=Decimal('60.28'), orderLineNumber=1)
# Row(orderNumber=10117, productCode='S12_1108', quantityOrdered=33, priceEach=Decimal('195.33'), orderLineNumber=9)
# Row(orderNumber=10117, productCode='S12_3148', quantityOrdered=43, priceEach=Decimal('148.06'), orderLineNumber=10)
# Row(orderNumber=10117, productCode='S12_3891', quantityOrdered=39, priceEach=Decimal('173.02'), orderLineNumber=8)
# Row(orderNumber=10117, productCode='S18_3140', quantityOrdered=26, priceEach=Decimal('121.57'), orderLineNumber=5)
# Row(orderNumber=10117, productCode='S18_3259', quantityOrdered=21, priceEach=Decimal('81.68'), orderLineNumber=7)
# Row(orderNumber=10117, productCode='S18_4027', quantityOrdered=22, priceEach=Decimal('122.08'), orderLineNumber=12)
# Row(orderNumber=10117, productCode='S18_4522', quantityOrdered=23, priceEach=Decimal('73.73'), orderLineNumber=4)
# Row(orderNumber=10117, productCode='S24_2011', quantityOrdered=41, priceEach=Decimal('119.20'), orderLineNumber=3)
# Row(orderNumber=10117, productCode='S50_1514', quantityOrdered=21, priceEach=Decimal('55.65'), orderLineNumber=11)
# Row(orderNumber=10117, productCode='S700_1938', quantityOrdered=38, priceEach=Decimal('75.35'), orderLineNumber=6)
# Row(orderNumber=10117, productCode='S700_3962', quantityOrdered=45, priceEach=Decimal('89.38'), orderLineNumber=1)
# Row(orderNumber=10117, productCode='S72_3212', quantityOrdered=50, priceEach=Decimal('52.42'), orderLineNumber=2)
# Row(orderNumber=10118, productCode='S700_3505', quantityOrdered=36, priceEach=Decimal('86.15'), orderLineNumber=1)
# Row(orderNumber=10119, productCode='S10_4757', quantityOrdered=46, priceEach=Decimal('112.88'), orderLineNumber=11)
# Row(orderNumber=10119, productCode='S18_1662', quantityOrdered=43, priceEach=Decimal('151.38'), orderLineNumber=3)
# Row(orderNumber=10119, productCode='S18_3029', quantityOrdered=21, priceEach=Decimal('74.84'), orderLineNumber=9)
# Row(orderNumber=10119, productCode='S18_3856', quantityOrdered=27, priceEach=Decimal('95.28'), orderLineNumber=8)
# Row(orderNumber=10119, productCode='S24_2841', quantityOrdered=41, priceEach=Decimal('64.40'), orderLineNumber=4)
# Row(orderNumber=10119, productCode='S24_3151', quantityOrdered=35, priceEach=Decimal('72.58'), orderLineNumber=13)
# Row(orderNumber=10119, productCode='S24_3420', quantityOrdered=20, priceEach=Decimal('63.12'), orderLineNumber=5)
# Row(orderNumber=10119, productCode='S24_3816', quantityOrdered=35, priceEach=Decimal('82.18'), orderLineNumber=10)
# Row(orderNumber=10119, productCode='S24_3949', quantityOrdered=28, priceEach=Decimal('62.10'), orderLineNumber=2)
# Row(orderNumber=10119, productCode='S700_1138', quantityOrdered=25, priceEach=Decimal('57.34'), orderLineNumber=14)
# Row(orderNumber=10119, productCode='S700_2047', quantityOrdered=29, priceEach=Decimal('74.23'), orderLineNumber=7)
# Row(orderNumber=10119, productCode='S700_2610', quantityOrdered=38, priceEach=Decimal('67.22'), orderLineNumber=12)
# Row(orderNumber=10119, productCode='S700_4002', quantityOrdered=26, priceEach=Decimal('63.67'), orderLineNumber=1)
# Row(orderNumber=10119, productCode='S72_1253', quantityOrdered=28, priceEach=Decimal('40.22'), orderLineNumber=6)
# Row(orderNumber=10120, productCode='S10_2016', quantityOrdered=29, priceEach=Decimal('118.94'), orderLineNumber=3)
# Row(orderNumber=10120, productCode='S10_4698', quantityOrdered=46, priceEach=Decimal('158.80'), orderLineNumber=2)
# Row(orderNumber=10120, productCode='S18_2581', quantityOrdered=29, priceEach=Decimal('82.79'), orderLineNumber=8)
# Row(orderNumber=10120, productCode='S18_2625', quantityOrdered=46, priceEach=Decimal('57.54'), orderLineNumber=4)
# Row(orderNumber=10120, productCode='S24_1578', quantityOrdered=35, priceEach=Decimal('110.45'), orderLineNumber=1)
# Row(orderNumber=10120, productCode='S24_1785', quantityOrdered=39, priceEach=Decimal('93.01'), orderLineNumber=10)
# Row(orderNumber=10120, productCode='S24_2000', quantityOrdered=34, priceEach=Decimal('72.36'), orderLineNumber=5)
# Row(orderNumber=10120, productCode='S24_4278', quantityOrdered=29, priceEach=Decimal('71.73'), orderLineNumber=9)
# Row(orderNumber=10120, productCode='S32_1374', quantityOrdered=22, priceEach=Decimal('94.90'), orderLineNumber=6)
# Row(orderNumber=10120, productCode='S32_4289', quantityOrdered=29, priceEach=Decimal('68.79'), orderLineNumber=11)
# Row(orderNumber=10120, productCode='S50_1341', quantityOrdered=49, priceEach=Decimal('41.46'), orderLineNumber=12)
# Row(orderNumber=10120, productCode='S700_1691', quantityOrdered=47, priceEach=Decimal('91.34'), orderLineNumber=13)
# Row(orderNumber=10120, productCode='S700_2466', quantityOrdered=24, priceEach=Decimal('81.77'), orderLineNumber=15)
# Row(orderNumber=10120, productCode='S700_2834', quantityOrdered=24, priceEach=Decimal('106.79'), orderLineNumber=7)
# Row(orderNumber=10120, productCode='S700_3167', quantityOrdered=43, priceEach=Decimal('72.00'), orderLineNumber=14)
# Row(orderNumber=10121, productCode='S10_1678', quantityOrdered=34, priceEach=Decimal('86.13'), orderLineNumber=5)
# Row(orderNumber=10121, productCode='S12_2823', quantityOrdered=50, priceEach=Decimal('126.52'), orderLineNumber=4)
# Row(orderNumber=10121, productCode='S24_2360', quantityOrdered=32, priceEach=Decimal('58.18'), orderLineNumber=2)
# Row(orderNumber=10121, productCode='S32_4485', quantityOrdered=25, priceEach=Decimal('95.93'), orderLineNumber=3)
# Row(orderNumber=10121, productCode='S50_4713', quantityOrdered=44, priceEach=Decimal('72.41'), orderLineNumber=1)
# Row(orderNumber=10122, productCode='S12_1099', quantityOrdered=42, priceEach=Decimal('155.66'), orderLineNumber=10)
# Row(orderNumber=10122, productCode='S12_3380', quantityOrdered=37, priceEach=Decimal('113.92'), orderLineNumber=8)
# Row(orderNumber=10122, productCode='S12_3990', quantityOrdered=32, priceEach=Decimal('65.44'), orderLineNumber=11)
# Row(orderNumber=10122, productCode='S12_4675', quantityOrdered=20, priceEach=Decimal('104.80'), orderLineNumber=7)
# Row(orderNumber=10122, productCode='S18_1129', quantityOrdered=34, priceEach=Decimal('114.65'), orderLineNumber=2)
# Row(orderNumber=10122, productCode='S18_1889', quantityOrdered=43, priceEach=Decimal('62.37'), orderLineNumber=6)
# Row(orderNumber=10122, productCode='S18_1984', quantityOrdered=31, priceEach=Decimal('113.80'), orderLineNumber=1)
# Row(orderNumber=10122, productCode='S18_3232', quantityOrdered=25, priceEach=Decimal('137.17'), orderLineNumber=3)
# Row(orderNumber=10122, productCode='S18_3278', quantityOrdered=21, priceEach=Decimal('69.15'), orderLineNumber=13)
# Row(orderNumber=10122, productCode='S18_3482', quantityOrdered=21, priceEach=Decimal('133.76'), orderLineNumber=12)
# Row(orderNumber=10122, productCode='S18_3782', quantityOrdered=35, priceEach=Decimal('59.06'), orderLineNumber=16)
# Row(orderNumber=10122, productCode='S18_4721', quantityOrdered=28, priceEach=Decimal('145.82'), orderLineNumber=15)
# Row(orderNumber=10122, productCode='S24_2972', quantityOrdered=39, priceEach=Decimal('34.74'), orderLineNumber=4)
# Row(orderNumber=10122, productCode='S24_3371', quantityOrdered=34, priceEach=Decimal('50.82'), orderLineNumber=9)
# Row(orderNumber=10122, productCode='S24_3856', quantityOrdered=43, priceEach=Decimal('136.22'), orderLineNumber=5)
# Row(orderNumber=10122, productCode='S24_4620', quantityOrdered=29, priceEach=Decimal('67.10'), orderLineNumber=14)
# Row(orderNumber=10122, productCode='S32_2206', quantityOrdered=31, priceEach=Decimal('33.79'), orderLineNumber=17)
# Row(orderNumber=10123, productCode='S18_1589', quantityOrdered=26, priceEach=Decimal('120.71'), orderLineNumber=2)
# Row(orderNumber=10123, productCode='S18_2870', quantityOrdered=46, priceEach=Decimal('114.84'), orderLineNumber=3)
# Row(orderNumber=10123, productCode='S18_3685', quantityOrdered=34, priceEach=Decimal('117.26'), orderLineNumber=4)
# Row(orderNumber=10123, productCode='S24_1628', quantityOrdered=50, priceEach=Decimal('43.27'), orderLineNumber=1)
# Row(orderNumber=10124, productCode='S18_1749', quantityOrdered=21, priceEach=Decimal('153.00'), orderLineNumber=6)
# Row(orderNumber=10124, productCode='S18_2248', quantityOrdered=42, priceEach=Decimal('58.12'), orderLineNumber=5)
# Row(orderNumber=10124, productCode='S18_2325', quantityOrdered=42, priceEach=Decimal('111.87'), orderLineNumber=3)
# Row(orderNumber=10124, productCode='S18_4409', quantityOrdered=36, priceEach=Decimal('75.46'), orderLineNumber=7)
# Row(orderNumber=10124, productCode='S18_4933', quantityOrdered=23, priceEach=Decimal('66.28'), orderLineNumber=8)
# Row(orderNumber=10124, productCode='S24_1046', quantityOrdered=22, priceEach=Decimal('62.47'), orderLineNumber=12)
# Row(orderNumber=10124, productCode='S24_1937', quantityOrdered=45, priceEach=Decimal('30.53'), orderLineNumber=2)
# Row(orderNumber=10124, productCode='S24_2022', quantityOrdered=22, priceEach=Decimal('36.29'), orderLineNumber=1)
# Row(orderNumber=10124, productCode='S24_2766', quantityOrdered=32, priceEach=Decimal('74.51'), orderLineNumber=10)
# Row(orderNumber=10124, productCode='S24_2887', quantityOrdered=25, priceEach=Decimal('93.95'), orderLineNumber=9)
# Row(orderNumber=10124, productCode='S24_3191', quantityOrdered=49, priceEach=Decimal('76.19'), orderLineNumber=11)
# Row(orderNumber=10124, productCode='S24_3432', quantityOrdered=43, priceEach=Decimal('101.73'), orderLineNumber=13)
# Row(orderNumber=10124, productCode='S24_3969', quantityOrdered=46, priceEach=Decimal('36.11'), orderLineNumber=4)
# Row(orderNumber=10125, productCode='S18_1342', quantityOrdered=32, priceEach=Decimal('89.38'), orderLineNumber=1)
# Row(orderNumber=10125, productCode='S18_2795', quantityOrdered=34, priceEach=Decimal('138.38'), orderLineNumber=2)
# Row(orderNumber=10126, productCode='S10_1949', quantityOrdered=38, priceEach=Decimal('205.73'), orderLineNumber=11)
# Row(orderNumber=10126, productCode='S10_4962', quantityOrdered=22, priceEach=Decimal('122.62'), orderLineNumber=4)
# Row(orderNumber=10126, productCode='S12_1666', quantityOrdered=21, priceEach=Decimal('135.30'), orderLineNumber=8)
# Row(orderNumber=10126, productCode='S18_1097', quantityOrdered=38, priceEach=Decimal('116.67'), orderLineNumber=10)
# Row(orderNumber=10126, productCode='S18_1367', quantityOrdered=42, priceEach=Decimal('51.21'), orderLineNumber=17)
# Row(orderNumber=10126, productCode='S18_2432', quantityOrdered=43, priceEach=Decimal('51.05'), orderLineNumber=2)
# Row(orderNumber=10126, productCode='S18_2949', quantityOrdered=31, priceEach=Decimal('93.21'), orderLineNumber=12)
# Row(orderNumber=10126, productCode='S18_2957', quantityOrdered=46, priceEach=Decimal('61.84'), orderLineNumber=14)
# Row(orderNumber=10126, productCode='S18_3136', quantityOrdered=30, priceEach=Decimal('93.20'), orderLineNumber=13)
# Row(orderNumber=10126, productCode='S18_3320', quantityOrdered=38, priceEach=Decimal('94.25'), orderLineNumber=16)
# Row(orderNumber=10126, productCode='S18_4600', quantityOrdered=50, priceEach=Decimal('102.92'), orderLineNumber=5)
# Row(orderNumber=10126, productCode='S18_4668', quantityOrdered=43, priceEach=Decimal('47.29'), orderLineNumber=9)
# Row(orderNumber=10126, productCode='S24_2300', quantityOrdered=27, priceEach=Decimal('122.68'), orderLineNumber=1)
# Row(orderNumber=10126, productCode='S24_4258', quantityOrdered=34, priceEach=Decimal('83.76'), orderLineNumber=15)
# Row(orderNumber=10126, productCode='S32_1268', quantityOrdered=43, priceEach=Decimal('82.83'), orderLineNumber=3)
# Row(orderNumber=10126, productCode='S32_3522', quantityOrdered=26, priceEach=Decimal('62.05'), orderLineNumber=7)
# Row(orderNumber=10126, productCode='S700_2824', quantityOrdered=45, priceEach=Decimal('97.10'), orderLineNumber=6)
# Row(orderNumber=10127, productCode='S12_1108', quantityOrdered=46, priceEach=Decimal('193.25'), orderLineNumber=2)
# Row(orderNumber=10127, productCode='S12_3148', quantityOrdered=46, priceEach=Decimal('140.50'), orderLineNumber=3)
# Row(orderNumber=10127, productCode='S12_3891', quantityOrdered=42, priceEach=Decimal('169.56'), orderLineNumber=1)
# Row(orderNumber=10127, productCode='S12_4473', quantityOrdered=24, priceEach=Decimal('100.73'), orderLineNumber=11)
# Row(orderNumber=10127, productCode='S18_2238', quantityOrdered=45, priceEach=Decimal('140.81'), orderLineNumber=10)
# Row(orderNumber=10127, productCode='S18_2319', quantityOrdered=45, priceEach=Decimal('114.14'), orderLineNumber=14)
# Row(orderNumber=10127, productCode='S18_3232', quantityOrdered=22, priceEach=Decimal('149.02'), orderLineNumber=15)
# Row(orderNumber=10127, productCode='S18_4027', quantityOrdered=25, priceEach=Decimal('126.39'), orderLineNumber=5)
# Row(orderNumber=10127, productCode='S24_1444', quantityOrdered=20, priceEach=Decimal('50.86'), orderLineNumber=8)
# Row(orderNumber=10127, productCode='S24_2840', quantityOrdered=39, priceEach=Decimal('34.30'), orderLineNumber=12)
# Row(orderNumber=10127, productCode='S24_4048', quantityOrdered=20, priceEach=Decimal('107.63'), orderLineNumber=7)
# Row(orderNumber=10127, productCode='S32_2509', quantityOrdered=45, priceEach=Decimal('46.53'), orderLineNumber=13)
# Row(orderNumber=10127, productCode='S32_3207', quantityOrdered=29, priceEach=Decimal('60.90'), orderLineNumber=6)
# Row(orderNumber=10127, productCode='S50_1392', quantityOrdered=46, priceEach=Decimal('111.12'), orderLineNumber=9)
# Row(orderNumber=10127, productCode='S50_1514', quantityOrdered=46, priceEach=Decimal('55.65'), orderLineNumber=4)
# Row(orderNumber=10128, productCode='S18_3140', quantityOrdered=41, priceEach=Decimal('120.20'), orderLineNumber=2)
# Row(orderNumber=10128, productCode='S18_3259', quantityOrdered=41, priceEach=Decimal('80.67'), orderLineNumber=4)
# Row(orderNumber=10128, productCode='S18_4522', quantityOrdered=43, priceEach=Decimal('77.24'), orderLineNumber=1)
# Row(orderNumber=10128, productCode='S700_1938', quantityOrdered=32, priceEach=Decimal('72.75'), orderLineNumber=3)
# Row(orderNumber=10129, productCode='S10_4757', quantityOrdered=33, priceEach=Decimal('123.76'), orderLineNumber=2)
# Row(orderNumber=10129, productCode='S24_2011', quantityOrdered=45, priceEach=Decimal('113.06'), orderLineNumber=9)
# Row(orderNumber=10129, productCode='S24_3151', quantityOrdered=41, priceEach=Decimal('81.43'), orderLineNumber=4)
# Row(orderNumber=10129, productCode='S24_3816', quantityOrdered=50, priceEach=Decimal('76.31'), orderLineNumber=1)
# Row(orderNumber=10129, productCode='S700_1138', quantityOrdered=31, priceEach=Decimal('58.67'), orderLineNumber=5)
# Row(orderNumber=10129, productCode='S700_2610', quantityOrdered=45, priceEach=Decimal('72.28'), orderLineNumber=3)
# Row(orderNumber=10129, productCode='S700_3505', quantityOrdered=42, priceEach=Decimal('90.15'), orderLineNumber=6)
# Row(orderNumber=10129, productCode='S700_3962', quantityOrdered=30, priceEach=Decimal('94.34'), orderLineNumber=7)
# Row(orderNumber=10129, productCode='S72_3212', quantityOrdered=32, priceEach=Decimal('44.23'), orderLineNumber=8)
# Row(orderNumber=10130, productCode='S18_3029', quantityOrdered=40, priceEach=Decimal('68.82'), orderLineNumber=2)
# Row(orderNumber=10130, productCode='S18_3856', quantityOrdered=33, priceEach=Decimal('99.52'), orderLineNumber=1)
# Row(orderNumber=10131, productCode='S18_1662', quantityOrdered=21, priceEach=Decimal('141.92'), orderLineNumber=4)
# Row(orderNumber=10131, productCode='S24_2841', quantityOrdered=35, priceEach=Decimal('60.97'), orderLineNumber=5)
# Row(orderNumber=10131, productCode='S24_3420', quantityOrdered=29, priceEach=Decimal('52.60'), orderLineNumber=6)
# Row(orderNumber=10131, productCode='S24_3949', quantityOrdered=50, priceEach=Decimal('54.59'), orderLineNumber=3)
# Row(orderNumber=10131, productCode='S700_2047', quantityOrdered=22, priceEach=Decimal('76.94'), orderLineNumber=8)
# Row(orderNumber=10131, productCode='S700_2466', quantityOrdered=40, priceEach=Decimal('86.76'), orderLineNumber=1)
# Row(orderNumber=10131, productCode='S700_4002', quantityOrdered=26, priceEach=Decimal('63.67'), orderLineNumber=2)
# Row(orderNumber=10131, productCode='S72_1253', quantityOrdered=21, priceEach=Decimal('40.22'), orderLineNumber=7)
# Row(orderNumber=10132, productCode='S700_3167', quantityOrdered=36, priceEach=Decimal('80.00'), orderLineNumber=1)
# Row(orderNumber=10133, productCode='S18_2581', quantityOrdered=49, priceEach=Decimal('80.26'), orderLineNumber=3)
# Row(orderNumber=10133, productCode='S24_1785', quantityOrdered=41, priceEach=Decimal('109.42'), orderLineNumber=5)
# Row(orderNumber=10133, productCode='S24_4278', quantityOrdered=46, priceEach=Decimal('61.58'), orderLineNumber=4)
# Row(orderNumber=10133, productCode='S32_1374', quantityOrdered=23, priceEach=Decimal('80.91'), orderLineNumber=1)
# Row(orderNumber=10133, productCode='S32_4289', quantityOrdered=49, priceEach=Decimal('67.41'), orderLineNumber=6)
# Row(orderNumber=10133, productCode='S50_1341', quantityOrdered=27, priceEach=Decimal('37.09'), orderLineNumber=7)
# Row(orderNumber=10133, productCode='S700_1691', quantityOrdered=24, priceEach=Decimal('76.73'), orderLineNumber=8)
# Row(orderNumber=10133, productCode='S700_2834', quantityOrdered=27, priceEach=Decimal('115.09'), orderLineNumber=2)
# Row(orderNumber=10134, productCode='S10_1678', quantityOrdered=41, priceEach=Decimal('90.92'), orderLineNumber=2)
# Row(orderNumber=10134, productCode='S10_2016', quantityOrdered=27, priceEach=Decimal('116.56'), orderLineNumber=5)
# Row(orderNumber=10134, productCode='S10_4698', quantityOrdered=31, priceEach=Decimal('187.85'), orderLineNumber=4)
# Row(orderNumber=10134, productCode='S12_2823', quantityOrdered=20, priceEach=Decimal('131.04'), orderLineNumber=1)
# Row(orderNumber=10134, productCode='S18_2625', quantityOrdered=30, priceEach=Decimal('51.48'), orderLineNumber=6)
# Row(orderNumber=10134, productCode='S24_1578', quantityOrdered=35, priceEach=Decimal('94.67'), orderLineNumber=3)
# Row(orderNumber=10134, productCode='S24_2000', quantityOrdered=43, priceEach=Decimal('75.41'), orderLineNumber=7)
# Row(orderNumber=10135, productCode='S12_1099', quantityOrdered=42, priceEach=Decimal('173.17'), orderLineNumber=7)
# Row(orderNumber=10135, productCode='S12_3380', quantityOrdered=48, priceEach=Decimal('110.39'), orderLineNumber=5)
# Row(orderNumber=10135, productCode='S12_3990', quantityOrdered=24, priceEach=Decimal('72.62'), orderLineNumber=8)
# Row(orderNumber=10135, productCode='S12_4675', quantityOrdered=29, priceEach=Decimal('103.64'), orderLineNumber=4)
# Row(orderNumber=10135, productCode='S18_1889', quantityOrdered=48, priceEach=Decimal('66.99'), orderLineNumber=3)
# Row(orderNumber=10135, productCode='S18_3278', quantityOrdered=45, priceEach=Decimal('65.94'), orderLineNumber=10)
# Row(orderNumber=10135, productCode='S18_3482', quantityOrdered=42, priceEach=Decimal('139.64'), orderLineNumber=9)
# Row(orderNumber=10135, productCode='S18_3782', quantityOrdered=45, priceEach=Decimal('49.74'), orderLineNumber=13)
# Row(orderNumber=10135, productCode='S18_4721', quantityOrdered=31, priceEach=Decimal('133.92'), orderLineNumber=12)
# Row(orderNumber=10135, productCode='S24_2360', quantityOrdered=29, priceEach=Decimal('67.18'), orderLineNumber=16)
# Row(orderNumber=10135, productCode='S24_2972', quantityOrdered=20, priceEach=Decimal('34.36'), orderLineNumber=1)
# Row(orderNumber=10135, productCode='S24_3371', quantityOrdered=27, priceEach=Decimal('52.05'), orderLineNumber=6)
# Row(orderNumber=10135, productCode='S24_3856', quantityOrdered=47, priceEach=Decimal('139.03'), orderLineNumber=2)
# Row(orderNumber=10135, productCode='S24_4620', quantityOrdered=23, priceEach=Decimal('76.80'), orderLineNumber=11)
# Row(orderNumber=10135, productCode='S32_2206', quantityOrdered=33, priceEach=Decimal('38.62'), orderLineNumber=14)
# Row(orderNumber=10135, productCode='S32_4485', quantityOrdered=30, priceEach=Decimal('91.85'), orderLineNumber=17)
# Row(orderNumber=10135, productCode='S50_4713', quantityOrdered=44, priceEach=Decimal('78.92'), orderLineNumber=15)
# Row(orderNumber=10136, productCode='S18_1129', quantityOrdered=25, priceEach=Decimal('117.48'), orderLineNumber=2)
# Row(orderNumber=10136, productCode='S18_1984', quantityOrdered=36, priceEach=Decimal('120.91'), orderLineNumber=1)
# Row(orderNumber=10136, productCode='S18_3232', quantityOrdered=41, priceEach=Decimal('169.34'), orderLineNumber=3)
# Row(orderNumber=10137, productCode='S18_1589', quantityOrdered=44, priceEach=Decimal('115.73'), orderLineNumber=2)
# Row(orderNumber=10137, productCode='S18_2870', quantityOrdered=37, priceEach=Decimal('110.88'), orderLineNumber=3)
# Row(orderNumber=10137, productCode='S18_3685', quantityOrdered=31, priceEach=Decimal('118.68'), orderLineNumber=4)
# Row(orderNumber=10137, productCode='S24_1628', quantityOrdered=26, priceEach=Decimal('40.25'), orderLineNumber=1)
# Row(orderNumber=10138, productCode='S18_1749', quantityOrdered=33, priceEach=Decimal('149.60'), orderLineNumber=6)
# Row(orderNumber=10138, productCode='S18_2248', quantityOrdered=22, priceEach=Decimal('51.46'), orderLineNumber=5)
# Row(orderNumber=10138, productCode='S18_2325', quantityOrdered=38, priceEach=Decimal('114.42'), orderLineNumber=3)
# Row(orderNumber=10138, productCode='S18_4409', quantityOrdered=47, priceEach=Decimal('79.15'), orderLineNumber=7)
# Row(orderNumber=10138, productCode='S18_4933', quantityOrdered=23, priceEach=Decimal('64.86'), orderLineNumber=8)
# Row(orderNumber=10138, productCode='S24_1046', quantityOrdered=45, priceEach=Decimal('59.53'), orderLineNumber=12)
# Row(orderNumber=10138, productCode='S24_1937', quantityOrdered=22, priceEach=Decimal('33.19'), orderLineNumber=2)
# Row(orderNumber=10138, productCode='S24_2022', quantityOrdered=33, priceEach=Decimal('38.53'), orderLineNumber=1)
# Row(orderNumber=10138, productCode='S24_2766', quantityOrdered=28, priceEach=Decimal('73.60'), orderLineNumber=10)
# Row(orderNumber=10138, productCode='S24_2887', quantityOrdered=30, priceEach=Decimal('96.30'), orderLineNumber=9)
# Row(orderNumber=10138, productCode='S24_3191', quantityOrdered=49, priceEach=Decimal('77.05'), orderLineNumber=11)
# Row(orderNumber=10138, productCode='S24_3432', quantityOrdered=21, priceEach=Decimal('99.58'), orderLineNumber=13)
# Row(orderNumber=10138, productCode='S24_3969', quantityOrdered=29, priceEach=Decimal('32.82'), orderLineNumber=4)
# Row(orderNumber=10139, productCode='S18_1342', quantityOrdered=31, priceEach=Decimal('89.38'), orderLineNumber=7)
# Row(orderNumber=10139, productCode='S18_1367', quantityOrdered=49, priceEach=Decimal('52.83'), orderLineNumber=6)
# Row(orderNumber=10139, productCode='S18_2795', quantityOrdered=41, priceEach=Decimal('151.88'), orderLineNumber=8)
# Row(orderNumber=10139, productCode='S18_2949', quantityOrdered=46, priceEach=Decimal('91.18'), orderLineNumber=1)
# Row(orderNumber=10139, productCode='S18_2957', quantityOrdered=20, priceEach=Decimal('52.47'), orderLineNumber=3)
# Row(orderNumber=10139, productCode='S18_3136', quantityOrdered=20, priceEach=Decimal('101.58'), orderLineNumber=2)
# Row(orderNumber=10139, productCode='S18_3320', quantityOrdered=30, priceEach=Decimal('81.35'), orderLineNumber=5)
# Row(orderNumber=10139, productCode='S24_4258', quantityOrdered=29, priceEach=Decimal('93.49'), orderLineNumber=4)
# Row(orderNumber=10140, productCode='S10_1949', quantityOrdered=37, priceEach=Decimal('186.44'), orderLineNumber=11)
# Row(orderNumber=10140, productCode='S10_4962', quantityOrdered=26, priceEach=Decimal('131.49'), orderLineNumber=4)
# Row(orderNumber=10140, productCode='S12_1666', quantityOrdered=38, priceEach=Decimal('118.90'), orderLineNumber=8)
# Row(orderNumber=10140, productCode='S18_1097', quantityOrdered=32, priceEach=Decimal('95.67'), orderLineNumber=10)
# Row(orderNumber=10140, productCode='S18_2432', quantityOrdered=46, priceEach=Decimal('51.05'), orderLineNumber=2)
# Row(orderNumber=10140, productCode='S18_4600', quantityOrdered=40, priceEach=Decimal('100.50'), orderLineNumber=5)
# Row(orderNumber=10140, productCode='S18_4668', quantityOrdered=29, priceEach=Decimal('40.25'), orderLineNumber=9)
# Row(orderNumber=10140, productCode='S24_2300', quantityOrdered=47, priceEach=Decimal('118.84'), orderLineNumber=1)
# Row(orderNumber=10140, productCode='S32_1268', quantityOrdered=26, priceEach=Decimal('87.64'), orderLineNumber=3)
# Row(orderNumber=10140, productCode='S32_3522', quantityOrdered=28, priceEach=Decimal('62.05'), orderLineNumber=7)
# Row(orderNumber=10140, productCode='S700_2824', quantityOrdered=36, priceEach=Decimal('101.15'), orderLineNumber=6)
# Row(orderNumber=10141, productCode='S12_4473', quantityOrdered=21, priceEach=Decimal('114.95'), orderLineNumber=5)
# Row(orderNumber=10141, productCode='S18_2238', quantityOrdered=39, priceEach=Decimal('160.46'), orderLineNumber=4)
# Row(orderNumber=10141, productCode='S18_2319', quantityOrdered=47, priceEach=Decimal('103.09'), orderLineNumber=8)
# Row(orderNumber=10141, productCode='S18_3232', quantityOrdered=34, priceEach=Decimal('143.94'), orderLineNumber=9)
# Row(orderNumber=10141, productCode='S24_1444', quantityOrdered=20, priceEach=Decimal('50.86'), orderLineNumber=2)
# Row(orderNumber=10141, productCode='S24_2840', quantityOrdered=21, priceEach=Decimal('32.18'), orderLineNumber=6)
# Row(orderNumber=10141, productCode='S24_4048', quantityOrdered=40, priceEach=Decimal('104.09'), orderLineNumber=1)
# Row(orderNumber=10141, productCode='S32_2509', quantityOrdered=24, priceEach=Decimal('53.03'), orderLineNumber=7)
# Row(orderNumber=10141, productCode='S50_1392', quantityOrdered=44, priceEach=Decimal('94.92'), orderLineNumber=3)
# Row(orderNumber=10142, productCode='S12_1108', quantityOrdered=33, priceEach=Decimal('166.24'), orderLineNumber=12)
# Row(orderNumber=10142, productCode='S12_3148', quantityOrdered=33, priceEach=Decimal('140.50'), orderLineNumber=13)
# Row(orderNumber=10142, productCode='S12_3891', quantityOrdered=46, priceEach=Decimal('167.83'), orderLineNumber=11)
# Row(orderNumber=10142, productCode='S18_3140', quantityOrdered=47, priceEach=Decimal('129.76'), orderLineNumber=8)
# Row(orderNumber=10142, productCode='S18_3259', quantityOrdered=22, priceEach=Decimal('95.80'), orderLineNumber=10)
# Row(orderNumber=10142, productCode='S18_4027', quantityOrdered=24, priceEach=Decimal('122.08'), orderLineNumber=15)
# Row(orderNumber=10142, productCode='S18_4522', quantityOrdered=24, priceEach=Decimal('79.87'), orderLineNumber=7)
# Row(orderNumber=10142, productCode='S24_2011', quantityOrdered=33, priceEach=Decimal('114.29'), orderLineNumber=6)
# Row(orderNumber=10142, productCode='S24_3151', quantityOrdered=49, priceEach=Decimal('74.35'), orderLineNumber=1)
# Row(orderNumber=10142, productCode='S32_3207', quantityOrdered=42, priceEach=Decimal('60.90'), orderLineNumber=16)
# Row(orderNumber=10142, productCode='S50_1514', quantityOrdered=42, priceEach=Decimal('56.24'), orderLineNumber=14)
# Row(orderNumber=10142, productCode='S700_1138', quantityOrdered=41, priceEach=Decimal('55.34'), orderLineNumber=2)
# Row(orderNumber=10142, productCode='S700_1938', quantityOrdered=43, priceEach=Decimal('77.08'), orderLineNumber=9)
# Row(orderNumber=10142, productCode='S700_3505', quantityOrdered=21, priceEach=Decimal('92.16'), orderLineNumber=3)
# Row(orderNumber=10142, productCode='S700_3962', quantityOrdered=38, priceEach=Decimal('91.37'), orderLineNumber=4)
# Row(orderNumber=10142, productCode='S72_3212', quantityOrdered=39, priceEach=Decimal('46.96'), orderLineNumber=5)
# Row(orderNumber=10143, productCode='S10_4757', quantityOrdered=49, priceEach=Decimal('133.28'), orderLineNumber=15)
# Row(orderNumber=10143, productCode='S18_1662', quantityOrdered=32, priceEach=Decimal('126.15'), orderLineNumber=7)
# Row(orderNumber=10143, productCode='S18_3029', quantityOrdered=46, priceEach=Decimal('70.54'), orderLineNumber=13)
# Row(orderNumber=10143, productCode='S18_3856', quantityOrdered=34, priceEach=Decimal('99.52'), orderLineNumber=12)
# Row(orderNumber=10143, productCode='S24_2841', quantityOrdered=27, priceEach=Decimal('63.71'), orderLineNumber=8)
# Row(orderNumber=10143, productCode='S24_3420', quantityOrdered=33, priceEach=Decimal('59.83'), orderLineNumber=9)
# Row(orderNumber=10143, productCode='S24_3816', quantityOrdered=23, priceEach=Decimal('74.64'), orderLineNumber=14)
# Row(orderNumber=10143, productCode='S24_3949', quantityOrdered=28, priceEach=Decimal('55.96'), orderLineNumber=6)
# Row(orderNumber=10143, productCode='S50_1341', quantityOrdered=34, priceEach=Decimal('34.91'), orderLineNumber=1)
# Row(orderNumber=10143, productCode='S700_1691', quantityOrdered=36, priceEach=Decimal('86.77'), orderLineNumber=2)
# Row(orderNumber=10143, productCode='S700_2047', quantityOrdered=26, priceEach=Decimal('87.80'), orderLineNumber=11)
# Row(orderNumber=10143, productCode='S700_2466', quantityOrdered=26, priceEach=Decimal('79.78'), orderLineNumber=4)
# Row(orderNumber=10143, productCode='S700_2610', quantityOrdered=31, priceEach=Decimal('69.39'), orderLineNumber=16)
# Row(orderNumber=10143, productCode='S700_3167', quantityOrdered=28, priceEach=Decimal('70.40'), orderLineNumber=3)
# Row(orderNumber=10143, productCode='S700_4002', quantityOrdered=34, priceEach=Decimal('65.15'), orderLineNumber=5)
# Row(orderNumber=10143, productCode='S72_1253', quantityOrdered=37, priceEach=Decimal('49.66'), orderLineNumber=10)
# Row(orderNumber=10144, productCode='S32_4289', quantityOrdered=20, priceEach=Decimal('56.41'), orderLineNumber=1)
# Row(orderNumber=10145, productCode='S10_1678', quantityOrdered=45, priceEach=Decimal('76.56'), orderLineNumber=6)
# Row(orderNumber=10145, productCode='S10_2016', quantityOrdered=37, priceEach=Decimal('104.67'), orderLineNumber=9)
# Row(orderNumber=10145, productCode='S10_4698', quantityOrdered=33, priceEach=Decimal('154.93'), orderLineNumber=8)
# Row(orderNumber=10145, productCode='S12_2823', quantityOrdered=49, priceEach=Decimal('146.10'), orderLineNumber=5)
# Row(orderNumber=10145, productCode='S18_2581', quantityOrdered=30, priceEach=Decimal('71.81'), orderLineNumber=14)
# Row(orderNumber=10145, productCode='S18_2625', quantityOrdered=30, priceEach=Decimal('52.70'), orderLineNumber=10)
# Row(orderNumber=10145, productCode='S24_1578', quantityOrdered=43, priceEach=Decimal('103.68'), orderLineNumber=7)
# Row(orderNumber=10145, productCode='S24_1785', quantityOrdered=40, priceEach=Decimal('87.54'), orderLineNumber=16)
# Row(orderNumber=10145, productCode='S24_2000', quantityOrdered=47, priceEach=Decimal('63.98'), orderLineNumber=11)
# Row(orderNumber=10145, productCode='S24_2360', quantityOrdered=27, priceEach=Decimal('56.10'), orderLineNumber=3)
# Row(orderNumber=10145, productCode='S24_4278', quantityOrdered=33, priceEach=Decimal('71.73'), orderLineNumber=15)
# Row(orderNumber=10145, productCode='S32_1374', quantityOrdered=33, priceEach=Decimal('99.89'), orderLineNumber=12)
# Row(orderNumber=10145, productCode='S32_2206', quantityOrdered=31, priceEach=Decimal('39.43'), orderLineNumber=1)
# Row(orderNumber=10145, productCode='S32_4485', quantityOrdered=27, priceEach=Decimal('95.93'), orderLineNumber=4)
# Row(orderNumber=10145, productCode='S50_4713', quantityOrdered=38, priceEach=Decimal('73.22'), orderLineNumber=2)
# Row(orderNumber=10145, productCode='S700_2834', quantityOrdered=20, priceEach=Decimal('113.90'), orderLineNumber=13)
# Row(orderNumber=10146, productCode='S18_3782', quantityOrdered=47, priceEach=Decimal('60.30'), orderLineNumber=2)
# Row(orderNumber=10146, productCode='S18_4721', quantityOrdered=29, priceEach=Decimal('130.94'), orderLineNumber=1)
# Row(orderNumber=10147, productCode='S12_1099', quantityOrdered=48, priceEach=Decimal('161.49'), orderLineNumber=7)
# Row(orderNumber=10147, productCode='S12_3380', quantityOrdered=31, priceEach=Decimal('110.39'), orderLineNumber=5)
# ...
# Row(orderNumber=10409, productCode='S24_1937', quantityOrdered=61, priceEach=Decimal('27.88'), orderLineNumber=1)
# Row(orderNumber=10410, productCode='S18_1342', quantityOrdered=65, priceEach=Decimal('99.66'), orderLineNumber=7)
# Row(orderNumber=10410, productCode='S18_1367', quantityOrdered=44, priceEach=Decimal('51.21'), orderLineNumber=6)
# Row(orderNumber=10410, productCode='S18_2795', quantityOrdered=56, priceEach=Decimal('145.13'), orderLineNumber=8)
# Row(orderNumber=10410, productCode='S18_2949', quantityOrdered=47, priceEach=Decimal('93.21'), orderLineNumber=1)
# Row(orderNumber=10410, productCode='S18_2957', quantityOrdered=53, priceEach=Decimal('49.97'), orderLineNumber=3)
# Row(orderNumber=10410, productCode='S18_3136', quantityOrdered=34, priceEach=Decimal('84.82'), orderLineNumber=2)
# Row(orderNumber=10410, productCode='S18_3320', quantityOrdered=44, priceEach=Decimal('81.35'), orderLineNumber=5)
# Row(orderNumber=10410, productCode='S24_2022', quantityOrdered=31, priceEach=Decimal('42.56'), orderLineNumber=9)
# Row(orderNumber=10410, productCode='S24_4258', quantityOrdered=50, priceEach=Decimal('95.44'), orderLineNumber=4)
# Row(orderNumber=10411, productCode='S10_1949', quantityOrdered=23, priceEach=Decimal('205.73'), orderLineNumber=9)
# Row(orderNumber=10411, productCode='S10_4962', quantityOrdered=27, priceEach=Decimal('144.79'), orderLineNumber=2)
# Row(orderNumber=10411, productCode='S12_1666', quantityOrdered=40, priceEach=Decimal('110.70'), orderLineNumber=6)
# Row(orderNumber=10411, productCode='S18_1097', quantityOrdered=27, priceEach=Decimal('109.67'), orderLineNumber=8)
# Row(orderNumber=10411, productCode='S18_4600', quantityOrdered=46, priceEach=Decimal('106.55'), orderLineNumber=3)
# Row(orderNumber=10411, productCode='S18_4668', quantityOrdered=35, priceEach=Decimal('41.25'), orderLineNumber=7)
# Row(orderNumber=10411, productCode='S32_1268', quantityOrdered=26, priceEach=Decimal('78.01'), orderLineNumber=1)
# Row(orderNumber=10411, productCode='S32_3522', quantityOrdered=27, priceEach=Decimal('60.76'), orderLineNumber=5)
# Row(orderNumber=10411, productCode='S700_2824', quantityOrdered=34, priceEach=Decimal('89.01'), orderLineNumber=4)
# Row(orderNumber=10412, productCode='S12_4473', quantityOrdered=54, priceEach=Decimal('100.73'), orderLineNumber=5)
# Row(orderNumber=10412, productCode='S18_2238', quantityOrdered=41, priceEach=Decimal('150.63'), orderLineNumber=4)
# Row(orderNumber=10412, productCode='S18_2319', quantityOrdered=56, priceEach=Decimal('120.28'), orderLineNumber=8)
# Row(orderNumber=10412, productCode='S18_2432', quantityOrdered=47, priceEach=Decimal('49.83'), orderLineNumber=11)
# Row(orderNumber=10412, productCode='S18_3232', quantityOrdered=60, priceEach=Decimal('157.49'), orderLineNumber=9)
# Row(orderNumber=10412, productCode='S24_1444', quantityOrdered=21, priceEach=Decimal('47.40'), orderLineNumber=2)
# Row(orderNumber=10412, productCode='S24_2300', quantityOrdered=70, priceEach=Decimal('109.90'), orderLineNumber=10)
# Row(orderNumber=10412, productCode='S24_2840', quantityOrdered=30, priceEach=Decimal('32.88'), orderLineNumber=6)
# Row(orderNumber=10412, productCode='S24_4048', quantityOrdered=31, priceEach=Decimal('108.82'), orderLineNumber=1)
# Row(orderNumber=10412, productCode='S32_2509', quantityOrdered=19, priceEach=Decimal('50.86'), orderLineNumber=7)
# Row(orderNumber=10412, productCode='S50_1392', quantityOrdered=26, priceEach=Decimal('105.33'), orderLineNumber=3)
# Row(orderNumber=10413, productCode='S12_1108', quantityOrdered=36, priceEach=Decimal('201.57'), orderLineNumber=2)
# Row(orderNumber=10413, productCode='S12_3148', quantityOrdered=47, priceEach=Decimal('145.04'), orderLineNumber=3)
# Row(orderNumber=10413, productCode='S12_3891', quantityOrdered=22, priceEach=Decimal('173.02'), orderLineNumber=1)
# Row(orderNumber=10413, productCode='S18_4027', quantityOrdered=49, priceEach=Decimal('133.57'), orderLineNumber=5)
# Row(orderNumber=10413, productCode='S32_3207', quantityOrdered=24, priceEach=Decimal('56.55'), orderLineNumber=6)
# Row(orderNumber=10413, productCode='S50_1514', quantityOrdered=51, priceEach=Decimal('53.31'), orderLineNumber=4)
# Row(orderNumber=10414, productCode='S10_4757', quantityOrdered=49, priceEach=Decimal('114.24'), orderLineNumber=3)
# Row(orderNumber=10414, productCode='S18_3029', quantityOrdered=44, priceEach=Decimal('77.42'), orderLineNumber=1)
# Row(orderNumber=10414, productCode='S18_3140', quantityOrdered=41, priceEach=Decimal('128.39'), orderLineNumber=12)
# Row(orderNumber=10414, productCode='S18_3259', quantityOrdered=48, priceEach=Decimal('85.71'), orderLineNumber=14)
# Row(orderNumber=10414, productCode='S18_4522', quantityOrdered=56, priceEach=Decimal('83.38'), orderLineNumber=11)
# Row(orderNumber=10414, productCode='S24_2011', quantityOrdered=43, priceEach=Decimal('108.14'), orderLineNumber=10)
# Row(orderNumber=10414, productCode='S24_3151', quantityOrdered=60, priceEach=Decimal('72.58'), orderLineNumber=5)
# Row(orderNumber=10414, productCode='S24_3816', quantityOrdered=51, priceEach=Decimal('72.96'), orderLineNumber=2)
# Row(orderNumber=10414, productCode='S700_1138', quantityOrdered=37, priceEach=Decimal('62.00'), orderLineNumber=6)
# Row(orderNumber=10414, productCode='S700_1938', quantityOrdered=34, priceEach=Decimal('74.48'), orderLineNumber=13)
# Row(orderNumber=10414, productCode='S700_2610', quantityOrdered=31, priceEach=Decimal('61.44'), orderLineNumber=4)
# Row(orderNumber=10414, productCode='S700_3505', quantityOrdered=28, priceEach=Decimal('84.14'), orderLineNumber=7)
# Row(orderNumber=10414, productCode='S700_3962', quantityOrdered=40, priceEach=Decimal('84.41'), orderLineNumber=8)
# Row(orderNumber=10414, productCode='S72_3212', quantityOrdered=47, priceEach=Decimal('54.60'), orderLineNumber=9)
# Row(orderNumber=10415, productCode='S18_3856', quantityOrdered=51, priceEach=Decimal('86.81'), orderLineNumber=5)
# Row(orderNumber=10415, productCode='S24_2841', quantityOrdered=21, priceEach=Decimal('60.97'), orderLineNumber=1)
# Row(orderNumber=10415, productCode='S24_3420', quantityOrdered=18, priceEach=Decimal('59.83'), orderLineNumber=2)
# Row(orderNumber=10415, productCode='S700_2047', quantityOrdered=32, priceEach=Decimal('73.32'), orderLineNumber=4)
# Row(orderNumber=10415, productCode='S72_1253', quantityOrdered=42, priceEach=Decimal('43.20'), orderLineNumber=3)
# Row(orderNumber=10416, productCode='S18_1662', quantityOrdered=24, priceEach=Decimal('129.31'), orderLineNumber=14)
# Row(orderNumber=10416, productCode='S18_2581', quantityOrdered=15, priceEach=Decimal('70.96'), orderLineNumber=4)
# Row(orderNumber=10416, productCode='S24_1785', quantityOrdered=47, priceEach=Decimal('90.82'), orderLineNumber=6)
# Row(orderNumber=10416, productCode='S24_2000', quantityOrdered=32, priceEach=Decimal('62.46'), orderLineNumber=1)
# Row(orderNumber=10416, productCode='S24_3949', quantityOrdered=18, priceEach=Decimal('64.83'), orderLineNumber=13)
# Row(orderNumber=10416, productCode='S24_4278', quantityOrdered=48, priceEach=Decimal('70.28'), orderLineNumber=5)
# Row(orderNumber=10416, productCode='S32_1374', quantityOrdered=45, priceEach=Decimal('86.90'), orderLineNumber=2)
# Row(orderNumber=10416, productCode='S32_4289', quantityOrdered=26, priceEach=Decimal('68.10'), orderLineNumber=7)
# Row(orderNumber=10416, productCode='S50_1341', quantityOrdered=37, priceEach=Decimal('39.71'), orderLineNumber=8)
# Row(orderNumber=10416, productCode='S700_1691', quantityOrdered=23, priceEach=Decimal('88.60'), orderLineNumber=9)
# Row(orderNumber=10416, productCode='S700_2466', quantityOrdered=22, priceEach=Decimal('84.76'), orderLineNumber=11)
# Row(orderNumber=10416, productCode='S700_2834', quantityOrdered=41, priceEach=Decimal('98.48'), orderLineNumber=3)
# Row(orderNumber=10416, productCode='S700_3167', quantityOrdered=39, priceEach=Decimal('65.60'), orderLineNumber=10)
# Row(orderNumber=10416, productCode='S700_4002', quantityOrdered=43, priceEach=Decimal('63.67'), orderLineNumber=12)
# Row(orderNumber=10417, productCode='S10_1678', quantityOrdered=66, priceEach=Decimal('79.43'), orderLineNumber=2)
# Row(orderNumber=10417, productCode='S10_2016', quantityOrdered=45, priceEach=Decimal('116.56'), orderLineNumber=5)
# Row(orderNumber=10417, productCode='S10_4698', quantityOrdered=56, priceEach=Decimal('162.67'), orderLineNumber=4)
# Row(orderNumber=10417, productCode='S12_2823', quantityOrdered=21, priceEach=Decimal('144.60'), orderLineNumber=1)
# Row(orderNumber=10417, productCode='S18_2625', quantityOrdered=36, priceEach=Decimal('58.75'), orderLineNumber=6)
# Row(orderNumber=10417, productCode='S24_1578', quantityOrdered=35, priceEach=Decimal('109.32'), orderLineNumber=3)
# Row(orderNumber=10418, productCode='S18_3278', quantityOrdered=16, priceEach=Decimal('70.76'), orderLineNumber=2)
# Row(orderNumber=10418, productCode='S18_3482', quantityOrdered=27, priceEach=Decimal('139.64'), orderLineNumber=1)
# Row(orderNumber=10418, productCode='S18_3782', quantityOrdered=33, priceEach=Decimal('56.57'), orderLineNumber=5)
# Row(orderNumber=10418, productCode='S18_4721', quantityOrdered=28, priceEach=Decimal('120.53'), orderLineNumber=4)
# Row(orderNumber=10418, productCode='S24_2360', quantityOrdered=52, priceEach=Decimal('64.41'), orderLineNumber=8)
# Row(orderNumber=10418, productCode='S24_4620', quantityOrdered=10, priceEach=Decimal('66.29'), orderLineNumber=3)
# Row(orderNumber=10418, productCode='S32_2206', quantityOrdered=43, priceEach=Decimal('36.61'), orderLineNumber=6)
# Row(orderNumber=10418, productCode='S32_4485', quantityOrdered=50, priceEach=Decimal('100.01'), orderLineNumber=9)
# Row(orderNumber=10418, productCode='S50_4713', quantityOrdered=40, priceEach=Decimal('72.41'), orderLineNumber=7)
# Row(orderNumber=10419, productCode='S12_1099', quantityOrdered=12, priceEach=Decimal('182.90'), orderLineNumber=13)
# Row(orderNumber=10419, productCode='S12_3380', quantityOrdered=10, priceEach=Decimal('111.57'), orderLineNumber=11)
# Row(orderNumber=10419, productCode='S12_3990', quantityOrdered=34, priceEach=Decimal('64.64'), orderLineNumber=14)
# Row(orderNumber=10419, productCode='S12_4675', quantityOrdered=32, priceEach=Decimal('99.04'), orderLineNumber=10)
# Row(orderNumber=10419, productCode='S18_1129', quantityOrdered=38, priceEach=Decimal('117.48'), orderLineNumber=5)
# Row(orderNumber=10419, productCode='S18_1589', quantityOrdered=37, priceEach=Decimal('100.80'), orderLineNumber=1)
# Row(orderNumber=10419, productCode='S18_1889', quantityOrdered=39, priceEach=Decimal('67.76'), orderLineNumber=9)
# Row(orderNumber=10419, productCode='S18_1984', quantityOrdered=34, priceEach=Decimal('133.72'), orderLineNumber=4)
# Row(orderNumber=10419, productCode='S18_2870', quantityOrdered=55, priceEach=Decimal('116.16'), orderLineNumber=2)
# Row(orderNumber=10419, productCode='S18_3232', quantityOrdered=35, priceEach=Decimal('165.95'), orderLineNumber=6)
# Row(orderNumber=10419, productCode='S18_3685', quantityOrdered=43, priceEach=Decimal('114.44'), orderLineNumber=3)
# Row(orderNumber=10419, productCode='S24_2972', quantityOrdered=15, priceEach=Decimal('32.10'), orderLineNumber=7)
# Row(orderNumber=10419, productCode='S24_3371', quantityOrdered=55, priceEach=Decimal('52.66'), orderLineNumber=12)
# Row(orderNumber=10419, productCode='S24_3856', quantityOrdered=70, priceEach=Decimal('112.34'), orderLineNumber=8)
# Row(orderNumber=10420, productCode='S18_1749', quantityOrdered=37, priceEach=Decimal('153.00'), orderLineNumber=5)
# Row(orderNumber=10420, productCode='S18_2248', quantityOrdered=36, priceEach=Decimal('52.06'), orderLineNumber=4)
# Row(orderNumber=10420, productCode='S18_2325', quantityOrdered=45, priceEach=Decimal('116.96'), orderLineNumber=2)
# Row(orderNumber=10420, productCode='S18_4409', quantityOrdered=66, priceEach=Decimal('73.62'), orderLineNumber=6)
# Row(orderNumber=10420, productCode='S18_4933', quantityOrdered=36, priceEach=Decimal('68.42'), orderLineNumber=7)
# Row(orderNumber=10420, productCode='S24_1046', quantityOrdered=60, priceEach=Decimal('60.26'), orderLineNumber=11)
# Row(orderNumber=10420, productCode='S24_1628', quantityOrdered=37, priceEach=Decimal('48.80'), orderLineNumber=13)
# Row(orderNumber=10420, productCode='S24_1937', quantityOrdered=45, priceEach=Decimal('32.19'), orderLineNumber=1)
# Row(orderNumber=10420, productCode='S24_2766', quantityOrdered=39, priceEach=Decimal('76.33'), orderLineNumber=9)
# Row(orderNumber=10420, productCode='S24_2887', quantityOrdered=55, priceEach=Decimal('115.09'), orderLineNumber=8)
# Row(orderNumber=10420, productCode='S24_3191', quantityOrdered=35, priceEach=Decimal('77.05'), orderLineNumber=10)
# Row(orderNumber=10420, productCode='S24_3432', quantityOrdered=26, priceEach=Decimal('104.94'), orderLineNumber=12)
# Row(orderNumber=10420, productCode='S24_3969', quantityOrdered=15, priceEach=Decimal('35.29'), orderLineNumber=3)
# Row(orderNumber=10421, productCode='S18_2795', quantityOrdered=35, priceEach=Decimal('167.06'), orderLineNumber=1)
# Row(orderNumber=10421, productCode='S24_2022', quantityOrdered=40, priceEach=Decimal('44.80'), orderLineNumber=2)
# Row(orderNumber=10422, productCode='S18_1342', quantityOrdered=51, priceEach=Decimal('91.44'), orderLineNumber=2)
# Row(orderNumber=10422, productCode='S18_1367', quantityOrdered=25, priceEach=Decimal('47.44'), orderLineNumber=1)
# Row(orderNumber=10423, productCode='S18_2949', quantityOrdered=10, priceEach=Decimal('89.15'), orderLineNumber=1)
# Row(orderNumber=10423, productCode='S18_2957', quantityOrdered=31, priceEach=Decimal('56.21'), orderLineNumber=3)
# Row(orderNumber=10423, productCode='S18_3136', quantityOrdered=21, priceEach=Decimal('98.44'), orderLineNumber=2)
# Row(orderNumber=10423, productCode='S18_3320', quantityOrdered=21, priceEach=Decimal('80.36'), orderLineNumber=5)
# Row(orderNumber=10423, productCode='S24_4258', quantityOrdered=28, priceEach=Decimal('78.89'), orderLineNumber=4)
# Row(orderNumber=10424, productCode='S10_1949', quantityOrdered=50, priceEach=Decimal('201.44'), orderLineNumber=6)
# Row(orderNumber=10424, productCode='S12_1666', quantityOrdered=49, priceEach=Decimal('121.64'), orderLineNumber=3)
# Row(orderNumber=10424, productCode='S18_1097', quantityOrdered=54, priceEach=Decimal('108.50'), orderLineNumber=5)
# Row(orderNumber=10424, productCode='S18_4668', quantityOrdered=26, priceEach=Decimal('40.25'), orderLineNumber=4)
# Row(orderNumber=10424, productCode='S32_3522', quantityOrdered=44, priceEach=Decimal('54.94'), orderLineNumber=2)
# Row(orderNumber=10424, productCode='S700_2824', quantityOrdered=46, priceEach=Decimal('85.98'), orderLineNumber=1)
# Row(orderNumber=10425, productCode='S10_4962', quantityOrdered=38, priceEach=Decimal('131.49'), orderLineNumber=12)
# Row(orderNumber=10425, productCode='S12_4473', quantityOrdered=33, priceEach=Decimal('95.99'), orderLineNumber=4)
# Row(orderNumber=10425, productCode='S18_2238', quantityOrdered=28, priceEach=Decimal('147.36'), orderLineNumber=3)
# Row(orderNumber=10425, productCode='S18_2319', quantityOrdered=38, priceEach=Decimal('117.82'), orderLineNumber=7)
# Row(orderNumber=10425, productCode='S18_2432', quantityOrdered=19, priceEach=Decimal('48.62'), orderLineNumber=10)
# Row(orderNumber=10425, productCode='S18_3232', quantityOrdered=28, priceEach=Decimal('140.55'), orderLineNumber=8)
# Row(orderNumber=10425, productCode='S18_4600', quantityOrdered=38, priceEach=Decimal('107.76'), orderLineNumber=13)
# Row(orderNumber=10425, productCode='S24_1444', quantityOrdered=55, priceEach=Decimal('53.75'), orderLineNumber=1)
# Row(orderNumber=10425, productCode='S24_2300', quantityOrdered=49, priceEach=Decimal('127.79'), orderLineNumber=9)
# Row(orderNumber=10425, productCode='S24_2840', quantityOrdered=31, priceEach=Decimal('31.82'), orderLineNumber=5)
# Row(orderNumber=10425, productCode='S32_1268', quantityOrdered=41, priceEach=Decimal('83.79'), orderLineNumber=11)
# Row(orderNumber=10425, productCode='S32_2509', quantityOrdered=11, priceEach=Decimal('50.32'), orderLineNumber=6)
# Row(orderNumber=10425, productCode='S50_1392', quantityOrdered=18, priceEach=Decimal('94.92'), orderLineNumber=2)

# %% [markdown]
# ## Q2) 1.2  Load data from csv

# %%
def load_data_from_csv(spark :pyspark.sql.SparkSession, csv_file_name: str) \
                      -> pyspark.sql.DataFrame:
    '''
    Load data from CSV file 'csv_file_name' and return a spark Dataframe
    PS: The data files for this assignment are in 'data' folder
    You can access full path of 'data/' folder using 'DATA_FOLDER' variable
    from constants.py
    ''' 
    return spark.read.csv(constants.DATA_FOLDER + csv_file_name, header=True, inferSchema=True)

# %%
load_data_from_csv(spark, "customers.csv").show(truncate=False)
# Out:
# +--------------+----------------------------+---------------+----------------+-----------------+----------------------------+------------------------+-------------+--------+----------+---------+----------------------+-----------+
# |customerNumber|customerName                |contactLastName|contactFirstName|phone            |addressLine1                |addressLine2            |city         |state   |postalCode|country  |salesRepEmployeeNumber|creditLimit|
# +--------------+----------------------------+---------------+----------------+-----------------+----------------------------+------------------------+-------------+--------+----------+---------+----------------------+-----------+
# |103           |Atelier graphique           |Schmitt        |Carine          |40.32.2555       |54, rue Royale              |NULL                    |Nantes       |NULL    |44000     |France   |1370                  |21000.0    |
# |112           |Signal Gift Stores          |King           |Jean            |7025551838       |8489 Strong St.             |NULL                    |Las Vegas    |NV      |83030     |USA      |1166                  |71800.0    |
# |114           |Australian Collectors, Co.  |Ferguson       |Peter           |03 9520 4555     |636 St Kilda Road           |Level 3                 |Melbourne    |Victoria|3004      |Australia|1611                  |117300.0   |
# |119           |La Rochelle Gifts           |Labrune        |Janine          |40.67.8555       |67, rue des Cinquante Otages|NULL                    |Nantes       |NULL    |44000     |France   |1370                  |118200.0   |
# |121           |Baane Mini Imports          |Bergulfsen     |Jonas           |07-98 9555       |Erling Skakkes gate 78      |NULL                    |Stavern      |NULL    |4110      |Norway   |1504                  |81700.0    |
# |124           |Mini Gifts Distributors Ltd.|Nelson         |Susan           |4155551450       |5677 Strong St.             |NULL                    |San Rafael   |CA      |97562     |USA      |1165                  |210500.0   |
# |125           |Havel & Zbyszek Co          |Piestrzeniewicz|Zbyszek         |(26) 642-7555    |ul. Filtrowa 68             |NULL                    |Warszawa     |NULL    |01-012    |Poland   |NULL                  |0.0        |
# |128           |Blauer See Auto, Co.        |Keitel         |Roland          |+49 69 66 90 2555|Lyonerstr. 34               |NULL                    |Frankfurt    |NULL    |60528     |Germany  |1504                  |59700.0    |
# |129           |Mini Wheels Co.             |Murphy         |Julie           |6505555787       |5557 North Pendale Street   |NULL                    |San Francisco|CA      |94217     |USA      |1165                  |64600.0    |
# |131           |Land of Toys Inc.           |Lee            |Kwai            |2125557818       |897 Long Airport Avenue     |NULL                    |NYC          |NY      |10022     |USA      |1323                  |114900.0   |
# |141           |Euro+ Shopping Channel      |Freyre         |Diego           |(91) 555 94 44   |C/ Moralzarzal, 86          |NULL                    |Madrid       |NULL    |28034     |Spain    |1370                  |227600.0   |
# |144           |Volvo Model Replicas, Co    |Berglund       |Christina       |0921-12 3555     |Berguvsvägen  8             |NULL                    |Luleå        |NULL    |S-958 22  |Sweden   |1504                  |53100.0    |
# |145           |Danish Wholesale Imports    |Petersen       |Jytte           |31 12 3555       |Vinbæltet 34                |NULL                    |Kobenhavn    |NULL    |1734      |Denmark  |1401                  |83400.0    |
# |146           |Saveley & Henriot, Co.      |Saveley        |Mary            |78.32.5555       |2, rue du Commerce          |NULL                    |Lyon         |NULL    |69004     |France   |1337                  |123900.0   |
# |148           |Dragon Souveniers, Ltd.     |Natividad      |Eric            |+65 221 7555     |Bronz Sok.                  |Bronz Apt. 3/6 Tesvikiye|Singapore    |NULL    |079903    |Singapore|1621                  |103800.0   |
# |151           |Muscle Machine Inc          |Young          |Jeff            |2125557413       |4092 Furth Circle           |Suite 400               |NYC          |NY      |10022     |USA      |1286                  |138500.0   |
# |157           |Diecast Classics Inc.       |Leong          |Kelvin          |2155551555       |7586 Pompton St.            |NULL                    |Allentown    |PA      |70267     |USA      |1216                  |100600.0   |
# |161           |Technics Stores Inc.        |Hashimoto      |Juri            |6505556809       |9408 Furth Circle           |NULL                    |Burlingame   |CA      |94217     |USA      |1165                  |84600.0    |
# |166           |Handji Gifts& Co            |Victorino      |Wendy           |+65 224 1555     |106 Linden Road Sandown     |2nd Floor               |Singapore    |NULL    |069045    |Singapore|1612                  |97900.0    |
# |167           |Herkku Gifts                |Oeztan         |Veysel          |+47 2267 3215    |Brehmen St. 121             |PR 334 Sentrum          |Bergen       |NULL    |N 5804    |Norway   |1504                  |96800.0    |
# +--------------+----------------------------+---------------+----------------+-----------------+----------------------------+------------------------+-------------+--------+----------+---------+----------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# ## Q3) 1.3  Load data from flat file

# %%
def load_data_from_flatfile(spark :pyspark.sql.SparkSession, txt_file_name: str) \
                      -> pyspark.sql.DataFrame:
    '''
    Load data from flat file 'txt_file_name' separated with ':' and return a spark Dataframe
    PS: The data files for this assignment are in 'data' folder
    You can access full path of 'data/' folder using 'DATA_FOLDER' variable
    from constants.py
    '''
    return spark.read.csv(constants.DATA_FOLDER + txt_file_name, sep=':', header=True, inferSchema=True)

# %%
load_data_from_flatfile(spark, "payments.txt").show(truncate=False)
# Out:
# +--------------+-----------+-----------+---------+
# |customerNumber|checkNumber|paymentDate|amount   |
# +--------------+-----------+-----------+---------+
# |103           |HQ336336   |2004-10-19 |6066.78  |
# |103           |JM555205   |2003-06-05 |14571.44 |
# |103           |OM314933   |2004-12-18 |1676.14  |
# |112           |BO864823   |2004-12-17 |14191.12 |
# |112           |HQ55022    |2003-06-06 |32641.98 |
# |112           |ND748579   |2004-08-20 |33347.88 |
# |114           |GG31455    |2003-05-20 |45864.03 |
# |114           |MA765515   |2004-12-15 |82261.22 |
# |114           |NP603840   |2003-05-31 |7565.08  |
# |114           |NR27552    |2004-03-10 |44894.74 |
# |119           |DB933704   |2004-11-14 |19501.82 |
# |119           |LN373447   |2004-08-08 |47924.19 |
# |119           |NG94694    |2005-02-22 |49523.67 |
# |121           |DB889831   |2003-02-16 |50218.95 |
# |121           |FD317790   |2003-10-28 |1491.38  |
# |121           |KI831359   |2004-11-04 |17876.32 |
# |121           |MA302151   |2004-11-28 |34638.14 |
# |124           |AE215433   |2005-03-05 |101244.59|
# |124           |BG255406   |2004-08-28 |85410.87 |
# |124           |CQ287967   |2003-04-11 |11044.3  |
# +--------------+-----------+-----------+---------+
# only showing top 20 rows

# %%
'''customers = load_data_from_csv(spark, "customers.csv") 
employees = load_data_from_csv(spark, "employees.csv")
offices = load_data_from_csv(spark, "offices.csv") 
orderDetails = load_data_from_mysql(spark, "classicmodels", 'orderdetails')   
orders = load_data_from_csv(spark, "orders.csv")
payments = load_data_from_flatfile(spark, "payments.txt") 
productLines = load_data_from_csv(spark, "productlines.csv")
products = load_data_from_csv(spark, "products.csv")

customers = customers.withColumn("creditLimit", col("creditLimit").cast(IntegerType()))
orders = orders.withColumn("shippedDate", to_date(col("shippedDate"),"yyyy-MM-dd"))'''
# Out:
# 'customers = load_data_from_csv(spark, "customers.csv") \nemployees = load_data_from_csv(spark, "employees.csv")\noffices = load_data_from_csv(spark, "offices.csv") \norderDetails = load_data_from_mysql(spark, "classicmodels", \'orderdetails\')   \norders = load_data_from_csv(spark, "orders.csv")\npayments = load_data_from_flatfile(spark, "payments.txt") \nproductLines = load_data_from_csv(spark, "productlines.csv")\nproducts = load_data_from_csv(spark, "products.csv")\n\ncustomers = customers.withColumn("creditLimit", col("creditLimit").cast(IntegerType()))\norders = orders.withColumn("shippedDate", to_date(col("shippedDate"),"yyyy-MM-dd"))'

# %%
'''load_data_from_csv(spark, "customers.csv").createOrReplaceTempView("customers_sql")
load_data_from_csv(spark, "employees.csv").createOrReplaceTempView("employees_sql")
load_data_from_csv(spark, "offices.csv").createOrReplaceTempView("offices_sql")
load_data_from_mysql(spark, "classicmodels", 'orderdetails').createOrReplaceTempView("orderdetails_sql")
load_data_from_csv(spark, "orders.csv").createOrReplaceTempView("orders_sql")
load_data_from_flatfile(spark, "payments.txt").createOrReplaceTempView("payments_sql")
load_data_from_csv(spark, "productlines.csv").createOrReplaceTempView("productlines_sql")
load_data_from_csv(spark, "products.csv").createOrReplaceTempView("products_sql")'''
# Out:
# 'load_data_from_csv(spark, "customers.csv").createOrReplaceTempView("customers_sql")\nload_data_from_csv(spark, "employees.csv").createOrReplaceTempView("employees_sql")\nload_data_from_csv(spark, "offices.csv").createOrReplaceTempView("offices_sql")\nload_data_from_mysql(spark, "classicmodels", \'orderdetails\').createOrReplaceTempView("orderdetails_sql")\nload_data_from_csv(spark, "orders.csv").createOrReplaceTempView("orders_sql")\nload_data_from_flatfile(spark, "payments.txt").createOrReplaceTempView("payments_sql")\nload_data_from_csv(spark, "productlines.csv").createOrReplaceTempView("productlines_sql")\nload_data_from_csv(spark, "products.csv").createOrReplaceTempView("products_sql")'

# %% [markdown]
# # 2. Transformations

# %% [markdown]
# ## Q4) 2.1  Clean product's MSRP data

# %%
def clean_product_MSRP_column(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    '''
    Due to a data entry issues MSRP, the selling price is lower than its buyPrice for some
    products. Change MSRP to 1.4 times of the buyPrice for such products and cast it to two
    decimal places.
    
    Return a spark dataframe with following columns.
    |productCode|productName|productLine|productScale|productVendor|productDescription|quantityInStock|buyPrice|MSRP|
    '''

    products = load_data_from_csv(spark, "products.csv")
    products = products.withColumn("MSRP", when(col("MSRP") < col("buyPrice"), round(1.4*col("buyPrice"), 2)) \
               .otherwise(col("MSRP")))
    return products

# %%
products = clean_product_MSRP_column(spark)

# %% [markdown]
# ## Q5) 2.2  Apply explode on data

# %%
def explode_productLines_description(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    ''' 
    Split the productLines description into words and explode the it.

    Return a spark dataframe with following columns.
    |productLine|description|
    +-----------+------------+
    |Motorcycles|         Our|
    |Motorcycles| motorcycles|
    |Motorcycles|         are|
       ... so on

    '''
    pLines = load_data_from_csv(spark, "productlines.csv")
    pLines = pLines.withColumn("textDescription", split(col("textDescription"), " "))
    return pLines.select(pLines.productLine, explode(pLines.textDescription).alias('description'))

# %%
explode_productLines_description(spark).show()
# Out:
# +------------+------------+
# | productLine| description|
# +------------+------------+
# |Classic Cars|   Attention|
# |Classic Cars|         car|
# |Classic Cars|enthusiasts:|
# |Classic Cars|        Make|
# |Classic Cars|        your|
# |Classic Cars|     wildest|
# |Classic Cars|         car|
# |Classic Cars|   ownership|
# |Classic Cars|      dreams|
# |Classic Cars|        come|
# |Classic Cars|       true.|
# |Classic Cars|     Whether|
# |Classic Cars|         you|
# |Classic Cars|         are|
# |Classic Cars|     looking|
# |Classic Cars|         for|
# |Classic Cars|     classic|
# |Classic Cars|      muscle|
# |Classic Cars|       cars,|
# |Classic Cars|       dream|
# +------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Q6) 2.3  Struct

# %%
def get_customer_info(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    '''
    Return a consolidated customer info using structs.
    
    Return a spark dataframe with following columns.
    |custID|custName|country|#orders|totalMoneySpent|creditLimit|
    '''
    customer_schema = StructType([ \
      StructField("custID",StringType(),True), \
      StructField("custName",StringType(),True), \
      StructField("country",StringType(),True), \
      StructField("#orders",IntegerType(),True), \
      StructField("totalMoneySpent", DoubleType(), True), \
      StructField("creditLimit", IntegerType(), True), \
    ])

    orders = load_data_from_csv(spark, "orders.csv")
    customers = load_data_from_csv(spark, "customers.csv")
    payments = load_data_from_flatfile(spark, "payments.txt")
    oc = customers.join(orders, 'customerNumber', 'left').drop(orders.customerNumber).groupBy('customerNumber').count()
    pc = customers.join(payments, 'customerNumber', 'left').drop(payments.customerNumber).groupBy('customerNumber').agg(sum('amount'))
    customer_details = pc.join(oc, 'customerNumber').join(customers, 'customerNumber').select('customerNumber', 'customerName', \
                       'country', 'count', col('sum(amount)').alias('totalAmount'), 'creditLimit')
    
    return customer_details.toDF(*customer_schema.fieldNames())

# %%
get_customer_info(spark).show()
# Out:
# +------+--------------------+-----------+-------+------------------+-----------+
# |custID|            custName|    country|#orders|   totalMoneySpent|creditLimit|
# +------+--------------------+-----------+-------+------------------+-----------+
# |   148|Dragon Souveniers...|  Singapore|      5|         156251.03|   103800.0|
# |   471|Australian Collec...|  Australia|      3|44920.759999999995|    60300.0|
# |   496|   Kelly's Gift Shop|New Zealand|      4|         114497.19|   110000.0|
# |   458|Corrida Auto Repl...|      Spain|      3|         112440.09|   104600.0|
# |   481|  Raanan Stores, Inc|     Israel|      1|              null|        0.0|
# |   321|Corporate Gift Id...|        USA|      4|         132340.78|   105000.0|
# |   362|   Gifts4AllAges.com|        USA|      3|          33533.47|    41900.0|
# |   211|King Kong Collect...|  Hong Kong|      2|          45480.79|    58600.0|
# |   385|     Cruz & Sons Co.|Philippines|      3|           87468.3|    81500.0|
# |   406|   Auto Canal+ Petit|     France|      3|          86436.97|    95000.0|
# |   412|Extreme Desk Deco...|New Zealand|      3|          66704.94|    86800.0|
# |   103|   Atelier graphique|     France|      3|          22314.36|    21000.0|
# |   350|Marseille Mini Autos|     France|      3|          71547.53|    65000.0|
# |   223|     Natürlich Autos|    Germany|      1|              null|        0.0|
# |   409|Stuttgart Collect...|    Germany|      1|              null|        0.0|
# |   333|Australian Gift N...|  Australia|      3|          55190.16|    51600.0|
# |   128|Blauer See Auto, Co.|    Germany|      4|          75937.76|    59700.0|
# |   209|         Mini Caravy|     France|      3|          75859.32|    53800.0|
# |   319|       Mini Classics|        USA|      2|          78432.16|   102700.0|
# |   157|Diecast Classics ...|        USA|      4|          98509.25|   100600.0|
# +------+--------------------+-----------+-------+------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# ## Q7) 2.4  UDF

# %%
@udf
def categorize_products(buy_price):
    if buy_price < 40:
        return "Affordable"
    elif buy_price < 80:
        return "Moderate"
    else:
        return "Expensive"
    
def retrun_product_category(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    ''' 
    Add a new column 'productCategory' using above udf and return the updated dataframe
    Note: Please do not change original dataframe.

    Return a spark dataframe with following columns.
    |productCode|productName|productLine|productScale|productVendor|productDescription \
    |quantityInStock|buyPrice|MSRP|productCategory|
    '''
    products = load_data_from_csv(spark, "products.csv")
    products = products.withColumn('buyPrice', when(col('buyPrice').cast("integer").isNotNull(), \
                                col('buyPrice').cast("integer")).otherwise(0))
    return products.withColumn("productCategory", categorize_products(products["buyPrice"]))

# %%
retrun_product_category(spark).show()
# Out:
# +-----------+--------------------+----------------+------------+--------------------+--------------------+---------------+--------+------+---------------+
# |productCode|         productName|     productLine|productScale|       productVendor|  productDescription|quantityInStock|buyPrice|  MSRP|productCategory|
# +-----------+--------------------+----------------+------------+--------------------+--------------------+---------------+--------+------+---------------+
# |   S10_1678|1969 Harley David...|     Motorcycles|       01:10|     Min Lin Diecast|This replica feat...|           7933|      48|  95.7|       Moderate|
# |   S10_1949|1952 Alpine Renau...|    Classic Cars|       01:10|Classic Metal Cre...|Turnable front wh...|           7305|      98| 214.3|      Expensive|
# |   S10_2016|1996 Moto Guzzi 1...|     Motorcycles|       01:10|Highway 66 Mini C...|Official Moto Guz...|           6625|      68|118.94|       Moderate|
# |   S10_4698|2003 Harley-David...|     Motorcycles|       01:10|   Red Start Diecast|Model features, o...|           5582|      91|193.66|      Expensive|
# |   S10_4757| 1972 Alfa Romeo GTA|    Classic Cars|       01:10|Motor City Art Cl...|Features include:...|           3252|      85| 136.0|      Expensive|
# |   S10_4962|1962 LanciaA Delt...|    Classic Cars|       01:10| Second Gear Diecast|Features include:...|           6791|     103|147.74|      Expensive|
# |   S12_1099|   1968 Ford Mustang|    Classic Cars|       01:12|Autoart Studio De...|Hood, doors and t...|             68|      95|194.57|      Expensive|
# |   S12_1108|   2001 Ferrari Enzo|    Classic Cars|       01:12| Second Gear Diecast|Turnable front wh...|           3619|      95| 207.8|      Expensive|
# |   S12_1666|      1958 Setra Bus|Trucks and Buses|       01:12|Welly Diecast Pro...|Model features 30...|           1579|      77| 36.67|       Moderate|
# |   S12_2823|    2002 Suzuki XREO|     Motorcycles|       01:12|Unimax Art Galleries|Official logos an...|           9997|      66|150.62|       Moderate|
# |   S12_3148|  1969 Corvair Monza|    Classic Cars|       01:18|Welly Diecast Pro...|1:18 scale die-ca...|           6906|      89|151.08|      Expensive|
# |   S12_3380|  1968 Dodge Charger|    Classic Cars|       01:12|Welly Diecast Pro...|1:12 scale model ...|           9123|      75|117.44|       Moderate|
# |   S12_3891|    1969 Ford Falcon|    Classic Cars|       01:12| Second Gear Diecast|Turnable front wh...|           1049|      83|173.02|      Expensive|
# |   S12_3990|1970 Plymouth Hem...|    Classic Cars|       01:12| Studio M Art Models|Very detailed 197...|           5663|      31|  79.8|     Affordable|
# |   S12_4473|   1957 Chevy Pickup|Trucks and Buses|       01:12|       Exoto Designs|1:12 scale die-ca...|           6125|      55| 118.5|       Moderate|
# |   S12_4675|  1969 Dodge Charger|    Classic Cars|       01:12|Welly Diecast Pro...|Detailed model of...|           7323|      58|115.16|       Moderate|
# |   S18_1097|1940 Ford Pickup ...|Trucks and Buses|       01:18| Studio M Art Models|This model featur...|           2613|      58|116.67|       Moderate|
# |   S18_1129|     1993 Mazda RX-7|    Classic Cars|       01:18|Highway 66 Mini C...|This model featur...|           3975|      83| 41.54|      Expensive|
# |   S18_1342|1937 Lincoln Berline|    Vintage Cars|       01:18|Motor City Art Cl...|Features opening ...|           8693|      60|102.74|       Moderate|
# |   S18_1367|1936 Mercedes-Ben...|    Vintage Cars|       01:18| Studio M Art Models|This 1:18 scale r...|           8635|      24| 53.91|     Affordable|
# +-----------+--------------------+----------------+------------+--------------------+--------------------+---------------+--------+------+---------------+
# only showing top 20 rows

# %% [markdown]
# ## Q8) 2.5  Rotate dataframe

# %%
def return_orders_by_day_by_status(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    '''
    Return No. of orders by weekday(1 to 7) by order status.

    Return a spark dataframe with following columns.
    +-------+---------+--------+----------+-------+--------+-------+
    |weekDay|Cancelled|Disputed|In Process|On Hold|Resolved|Shipped|
    +-------+---------+--------+----------+-------+--------+-------+
    |      1|     null|    null|         2|      1|    null|      8|
           2
           3 and so on
    '''
    orders = load_data_from_csv(spark, "orders.csv")
    return orders.select(dayofweek('orderDate').alias('weekDay'), '*').groupBy('weekDay').pivot('status') \
    .agg(count('orderNumber').alias('totalOrders')).orderBy('weekDay')

# %%
return_orders_by_day_by_status(spark).show()
# Out:
# +-------+---------+--------+----------+-------+--------+-------+
# |weekDay|Cancelled|Disputed|In Process|On Hold|Resolved|Shipped|
# +-------+---------+--------+----------+-------+--------+-------+
# |      1|     null|    null|         2|      1|    null|      8|
# |      2|     null|       1|         2|   null|    null|     47|
# |      3|        2|    null|         2|   null|       2|     50|
# |      4|        1|    null|      null|   null|       2|     61|
# |      5|        2|    null|      null|   null|    null|     57|
# |      6|        1|       2|      null|      3|    null|     63|
# |      7|     null|    null|      null|   null|    null|     17|
# +-------+---------+--------+----------+-------+--------+-------+

# %% [markdown]
# ## Q9) 2.6  Clean ProductLines text Description

# %%
def clean_productlines_description(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    '''
    Take testDescription from productLines table and clean it.
    1. Convert to lower-case
    2. Remove all special characters except a-z and 0-9.
    3. Remove stop words (using StopWordsRemover.loadDefaultStopWords("english"))
    The final value(testDescription) must be a string.
    
    Return a spark dataframe with following columns.
    |productLine|htmlDescription|image|textDescription|
    '''
    
    def remove_special_chars(words):
        return [word.lower().replace("[^a-z0-9 ]", "") for word in words]
    
    pLines = load_data_from_csv(spark, "productlines.csv")

    pLines = pLines.withColumn("textDescription", split(col("textDescription"), " "))
    remove_special_chars_udf = udf(remove_special_chars, ArrayType(StringType()))
    pLines = pLines.withColumn("textDescription", remove_special_chars_udf(col("textDescription")))

    stopwords = StopWordsRemover.loadDefaultStopWords("english")
    stopwords_remover = StopWordsRemover(inputCol="textDescription", outputCol="textDescription_wos", stopWords=stopwords)
    pLines = stopwords_remover.transform(pLines).drop("textDescription")

    pLines = pLines.withColumn("textDescription", concat_ws(" ", "textDescription_wos")).drop('textDescription_wos')

    return pLines

# %%
# productLines.show()
clean_productlines_description(spark).show()
# Out:
# +----------------+---------------+-----+--------------------+
# |     productLine|htmlDescription|image|     textDescription|
# +----------------+---------------+-----+--------------------+
# |    Classic Cars|           NULL| NULL|attention car ent...|
# |     Motorcycles|           NULL| NULL|motorcycles state...|
# |          Planes|           NULL| NULL|unique, diecast a...|
# |           Ships|           NULL| NULL|perfect holiday a...|
# |          Trains|           NULL| NULL|model trains rewa...|
# |Trucks and Buses|           NULL| NULL|truck bus models ...|
# |    Vintage Cars|           NULL| NULL|vintage car model...|
# +----------------+---------------+-----+--------------------+
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 55437)
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\socketserver.py", line 755, in __init__
#     self.handle()
#   File "C:\Users\Vinni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyspark\accumulators.py", line 281, in handle
#     poll(accum_updates)
#   File "C:\Users\Vinni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyspark\accumulators.py", line 253, in poll
#     if func():
#        ^^^^^^
#   File "C:\Users\Vinni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyspark\accumulators.py", line 257, in accum_updates
#     num_updates = read_int(self.rfile)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Vinni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyspark\serializers.py", line 594, in read_int
#     length = stream.read(4)
#              ^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ----------------------------------------

# %% [markdown]
# # 3. Analytics

# %% [markdown]
# ## Q10) 3.1 Your company wants to promote their top 5 employees who made maximum sales(orders)

# %%
def return_top_5_employees(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    '''
    Return the top 5 employees(Sales Representatives) who made maximum no. of
    sales throughout the given timeperiod. You can consider all sales with all statuses.
    
    Return a spark dataframe with following columns.
    employeeNumber|firstName|lastName |TotalOrders
    '''

    orders = load_data_from_csv(spark, "orders.csv")
    employees = load_data_from_csv(spark, "employees.csv")
    customers = load_data_from_csv(spark, "customers.csv")
    
    top_5_emp = orders.join(customers, 'customerNumber').groupBy('customerNumber').agg(count('orderNumber').alias('totalOrders'), \
                first('salesRepEmployeeNumber').alias('salesRepEmployeeNumber')).groupBy('salesRepEmployeeNumber') \
                .agg(sum('totalOrders').alias('totalOrders')).orderBy(col('totalOrders').desc()).limit(5) \
                .join(employees, col("salesRepEmployeeNumber")==employees.employeeNumber) \
                .select('firstName', 'lastName', 'totalOrders').orderBy(col('totalOrders').desc())
    return top_5_emp

# %%
return_top_5_employees(spark)
# Out:
# DataFrame[firstName: string, lastName: string, totalOrders: bigint]

# %% [markdown]
# ## Q11) 3.2 Imagine you are a sales representative. Mail your manager a report on cancelled orders

# %%
def report_cancelled_orders(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    '''
    Return email adresses of your manager to send a report about the cancelled orders. Return
    Order details and a column to define if the cancelled order has been shipped already
    or not('Yes' or  'No').
     
    Return a spark dataframe with following columns.
    +-----------+---------+--------------------+--------------+----------------------+---------+--------------------+
    |orderNumber|isShipped|            comments|customerNumber|salesRepEmployeeNumber|reportsTo|               email|
    +-----------+---------+--------------------+--------------+----------------------+---------+--------------------+
    |      10167|       No|Customer called t...|           448|                  1504|     1102|gbondur@classicmo...|
           ...
           ... so on
    '''
    
    load_data_from_csv(spark, "customers.csv").createOrReplaceTempView("customers_sql")
    load_data_from_csv(spark, "employees.csv").createOrReplaceTempView("employees_sql")
    load_data_from_csv(spark, "orders.csv").createOrReplaceTempView("orders_sql")


    emails = spark.sql(" select oce.*, email from employees_sql\
              join (select oc.*, reportsTo from employees_sql \
              join (select orders.*, salesRepEmployeeNumber from customers_sql \
              join (select orderNumber, case when shippedDate = 'NULL' then 'No' else 'Yes' end as isShipped, \
              comments, customerNumber from orders_sql where status='Cancelled') as orders \
              on customers_sql.customerNumber == orders.customerNumber) as oc \
              on employees_sql.employeeNumber == oc.salesRepEmployeeNumber) as oce \
              on employees_sql.employeeNumber == oce.reportsTo \
            ")
    return emails

# %%
report_cancelled_orders(spark).show()
# Out:
# +-----------+---------+--------------------+--------------+----------------------+---------+--------------------+
# |orderNumber|isShipped|            comments|customerNumber|salesRepEmployeeNumber|reportsTo|               email|
# +-----------+---------+--------------------+--------------+----------------------+---------+--------------------+
# |      10167|       No|Customer called t...|           448|                  1504|     1102|gbondur@classicmo...|
# |      10179|      Yes|Customer cancelle...|           496|                  1612|     1088|wpatterson@classi...|
# |      10248|       No|Order was mistake...|           131|                  1323|     1143|abow@classicmodel...|
# |      10253|      Yes|Customer disputed...|           201|                  1501|     1102|gbondur@classicmo...|
# |      10260|       No|Customer heard co...|           357|                  1612|     1088|wpatterson@classi...|
# |      10262|       No|This customer fou...|           141|                  1370|     1102|gbondur@classicmo...|
# +-----------+---------+--------------------+--------------+----------------------+---------+--------------------+

# %% [markdown]
# ## Q12) 3.3 Return Top 5 big spenders

# %%
def return_top_5_big_spenders(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    '''
    Return top 5 big spenders who had spent the most $(highest order value).
    
    Return a spark dataframe with following columns.
    customerNumber|customerName|totalOrderValue|
    '''
    
    customers_df = load_data_from_csv(spark, "customers.csv")
    orders_df = load_data_from_csv(spark, "orders.csv")
    orderdetails_df = load_data_from_mysql(spark, "classicmodels", 'orderdetails')
    merged_data = customers_df.join(orders_df, "customerNumber").join(orderdetails_df, "orderNumber")
    # Calculate the total order value for each customer
    total_order_value = merged_data.groupBy("customerNumber", "customerName") \
    .agg(sum(merged_data.priceEach * merged_data.quantityOrdered).alias("totalOrderValue")) \
    .orderBy(col('totalOrderValue').desc()).limit(5)
    # print(total_order_value.show(truncate=False))
    # Return the total order value DataFrame
    return total_order_value

# %%
return_top_5_big_spenders(spark).show(truncate=False)
# Out:
# +--------------+----------------------------+---------------+
# |customerNumber|customerName                |totalOrderValue|
# +--------------+----------------------------+---------------+
# |141           |Euro+ Shopping Channel      |820689.54      |
# |124           |Mini Gifts Distributors Ltd.|591827.34      |
# |114           |Australian Collectors, Co.  |180585.07      |
# |151           |Muscle Machine Inc          |177913.95      |
# |119           |La Rochelle Gifts           |158573.12      |
# +--------------+----------------------------+---------------+

# %% [markdown]
# ## Q13) 3.4 Return Top 5 big spenders(countries)

# %%
def return_top_5_big_spend_countries(spark :pyspark.sql.SparkSession) -> pyspark.sql.DataFrame:
    '''
    Return top 5 big countries which had spent the most $(highest order value).
    
    Return a spark dataframe with following columns.
    |country|totalOrderValue|
    '''
    
    customers_df = load_data_from_csv(spark, "customers.csv")
    orders_df = load_data_from_csv(spark, "orders.csv")
    orderdetails_df = load_data_from_mysql(spark, "classicmodels", 'orderdetails')
    merged_data = customers_df.join(orders_df, "customerNumber").join(orderdetails_df, "orderNumber")
    # Calculate the total order value for each customer
    total_order_value = merged_data.groupBy("country") \
    .agg(sum(merged_data.priceEach * merged_data.quantityOrdered).alias("totalOrderValue")) \
    .orderBy(col('totalOrderValue').desc()).limit(5)
    # print(total_order_value.show(truncate=False))
    # Return the total order value DataFrame
    return total_order_value

# %%
return_top_5_big_spend_countries(spark).show(truncate=False)
# Out:
# +-----------+---------------+
# |country    |totalOrderValue|
# +-----------+---------------+
# |USA        |3273280.05     |
# |Spain      |1099389.09     |
# |France     |1007374.02     |
# |Australia  |562582.59      |
# |New Zealand|476847.01      |
# +-----------+---------------+
